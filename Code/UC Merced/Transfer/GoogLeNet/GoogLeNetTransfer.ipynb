# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from contextlib import suppress
import matplotlib
import matplotlib.pyplot as plt

import numpy as np
import os
import warnings
#from zipfile import ZipFile

from skimage.io import imread, imsave

from keras import applications
from keras import optimizers
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, Flatten
from keras.utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import accuracy_score, classification_report
# Out:
# Using TensorFlow backend.

# %%
np.random.seed(8)

# %%
# !pwd
# %cd "drive/My Drive/CVProject"
# !pwd
# Out:
# /content
# /content/drive/My Drive/CVProject
# /content/drive/My Drive/CVProject

# %%
class_names = os.listdir('UCMerced_LandUse/Train/')
target_dirs = {target: './UCMerced_LandUse/' + target for target in ['Train', 'Validation', 'Test']}

# %%
print(class_names)
print(target_dirs)
# Out:
# ['agricultural', 'airplane', 'baseballdiamond', 'beach', 'buildings', 'chaparral', 'denseresidential', 'forest', 'freeway', 'golfcourse', 'harbor', 'intersection', 'mediumresidential', 'mobilehomepark', 'overpass', 'parkinglot', 'river', 'storagetanks', 'runway', 'tenniscourt', 'sparseresidential']
# {'Train': './UCMerced_LandUse/Train', 'Validation': './UCMerced_LandUse/Validation', 'Test': './UCMerced_LandUse/Test'}

# %%
def get_bottleneck_features(model, dataset, batch_size=64):
  print(f'Generating "{dataset}" bottleneck predictions')
  image_data_gen = ImageDataGenerator(rescale=1/255.0)
  image_generator = image_data_gen.flow_from_directory(target_dirs[dataset],
                                                        batch_size=batch_size,
                                                        shuffle=False)
  image_count = 0
  X_batches, Y_batches = [], []
  for X, Y in image_generator:
    X_batches.append(model.predict_on_batch(X))
    Y_batches.append(Y)
    image_count += X.shape[0]
    # Must interrupt image_generator
    if image_count >= image_generator.n:
      break
  X = np.concatenate(X_batches)
  Y = np.concatenate(Y_batches)
  return X, Y

# %%
pretrained_model = applications.InceptionV3(include_top=False, weights='imagenet')

# %%
num_classes = len(class_names)
X, Y = dict(), dict()
for dataset in [ 'Validation', 'Test', 'Train']:
    # Extract bottleneck features from pretrained model, predicting from "dataset" directory
    X[dataset], Y[dataset] = get_bottleneck_features(pretrained_model, dataset)
# Out:
# Generating "Validation" bottleneck predictions
# Found 210 images belonging to 21 classes.
# Generating "Test" bottleneck predictions
# Found 210 images belonging to 21 classes.
# Generating "Train" bottleneck predictions
# Found 1785 images belonging to 21 classes.

# %%
def build_fully_connected(input_shape, num_classes):
    """
    Create a fully-connected model to train or test on UC Merced dataset.
    """
    model = Sequential()
    model.add(Flatten(input_shape=input_shape))
    model.add(Dense(256))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    return model

# %%
model = build_fully_connected(input_shape=X['Train'].shape[1:], num_classes=num_classes)
adam = optimizers.Adam(lr=0.0002)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
model_fit_history = model.fit(X['Train'], Y['Train'], batch_size=64, epochs=300,
                              verbose=2, validation_data=(X['Validation'], Y['Validation']))
# Out:
# Train on 1785 samples, validate on 210 samples
# Epoch 1/300
#  - 1s - loss: 2.4985 - accuracy: 0.3955 - val_loss: 0.8820 - val_accuracy: 0.7762
# Epoch 2/300
#  - 1s - loss: 0.8284 - accuracy: 0.7395 - val_loss: 0.6062 - val_accuracy: 0.8095
# Epoch 3/300
#  - 1s - loss: 0.5006 - accuracy: 0.8398 - val_loss: 0.5041 - val_accuracy: 0.8429
# Epoch 4/300
#  - 1s - loss: 0.3346 - accuracy: 0.8980 - val_loss: 0.4308 - val_accuracy: 0.8619
# Epoch 5/300
#  - 1s - loss: 0.1949 - accuracy: 0.9440 - val_loss: 0.3943 - val_accuracy: 0.8762
# Epoch 6/300
#  - 1s - loss: 0.1849 - accuracy: 0.9462 - val_loss: 0.3734 - val_accuracy: 0.8762
# Epoch 7/300
#  - 1s - loss: 0.1219 - accuracy: 0.9613 - val_loss: 0.4498 - val_accuracy: 0.8619
# Epoch 8/300
#  - 1s - loss: 0.1073 - accuracy: 0.9703 - val_loss: 0.4100 - val_accuracy: 0.8619
# Epoch 9/300
#  - 1s - loss: 0.1045 - accuracy: 0.9709 - val_loss: 0.3903 - val_accuracy: 0.8810
# Epoch 10/300
#  - 1s - loss: 0.0863 - accuracy: 0.9725 - val_loss: 0.4180 - val_accuracy: 0.8714
# Epoch 11/300
#  - 1s - loss: 0.0977 - accuracy: 0.9748 - val_loss: 0.3848 - val_accuracy: 0.8714
# Epoch 12/300
#  - 1s - loss: 0.0587 - accuracy: 0.9843 - val_loss: 0.4465 - val_accuracy: 0.8905
# Epoch 13/300
#  - 1s - loss: 0.0643 - accuracy: 0.9782 - val_loss: 0.3996 - val_accuracy: 0.8667
# Epoch 14/300
#  - 1s - loss: 0.0658 - accuracy: 0.9821 - val_loss: 0.4449 - val_accuracy: 0.8714
# Epoch 15/300
#  - 1s - loss: 0.0635 - accuracy: 0.9826 - val_loss: 0.3989 - val_accuracy: 0.8619
# Epoch 16/300
#  - 1s - loss: 0.0613 - accuracy: 0.9838 - val_loss: 0.4337 - val_accuracy: 0.8667
# Epoch 17/300
#  - 1s - loss: 0.0474 - accuracy: 0.9866 - val_loss: 0.5421 - val_accuracy: 0.8619
# Epoch 18/300
#  - 1s - loss: 0.0528 - accuracy: 0.9826 - val_loss: 0.5309 - val_accuracy: 0.9000
# Epoch 19/300
#  - 1s - loss: 0.0523 - accuracy: 0.9854 - val_loss: 0.4380 - val_accuracy: 0.8667
# Epoch 20/300
#  - 1s - loss: 0.0396 - accuracy: 0.9899 - val_loss: 0.4134 - val_accuracy: 0.8952
# Epoch 21/300
#  - 1s - loss: 0.0451 - accuracy: 0.9860 - val_loss: 0.5083 - val_accuracy: 0.8714
# Epoch 22/300
#  - 1s - loss: 0.0425 - accuracy: 0.9854 - val_loss: 0.5092 - val_accuracy: 0.8571
# Epoch 23/300
#  - 1s - loss: 0.0562 - accuracy: 0.9826 - val_loss: 0.5006 - val_accuracy: 0.8762
# Epoch 24/300
#  - 1s - loss: 0.0358 - accuracy: 0.9916 - val_loss: 0.4987 - val_accuracy: 0.8905
# Epoch 25/300
#  - 1s - loss: 0.0370 - accuracy: 0.9871 - val_loss: 0.4613 - val_accuracy: 0.8810
# Epoch 26/300
#  - 1s - loss: 0.0335 - accuracy: 0.9905 - val_loss: 0.4850 - val_accuracy: 0.8952
# Epoch 27/300
#  - 1s - loss: 0.0381 - accuracy: 0.9877 - val_loss: 0.5113 - val_accuracy: 0.8619
# Epoch 28/300
#  - 1s - loss: 0.0395 - accuracy: 0.9871 - val_loss: 0.5051 - val_accuracy: 0.8810
# Epoch 29/300
#  - 1s - loss: 0.0307 - accuracy: 0.9905 - val_loss: 0.4109 - val_accuracy: 0.8810
# Epoch 30/300
#  - 1s - loss: 0.0297 - accuracy: 0.9899 - val_loss: 0.4758 - val_accuracy: 0.8905
# Epoch 31/300
#  - 1s - loss: 0.0263 - accuracy: 0.9916 - val_loss: 0.4059 - val_accuracy: 0.8857
# Epoch 32/300
#  - 1s - loss: 0.0323 - accuracy: 0.9916 - val_loss: 0.5528 - val_accuracy: 0.8714
# Epoch 33/300
#  - 1s - loss: 0.0397 - accuracy: 0.9877 - val_loss: 0.4871 - val_accuracy: 0.8810
# Epoch 34/300
#  - 1s - loss: 0.0315 - accuracy: 0.9894 - val_loss: 0.4805 - val_accuracy: 0.8857
# Epoch 35/300
#  - 1s - loss: 0.0275 - accuracy: 0.9933 - val_loss: 0.5362 - val_accuracy: 0.8810
# Epoch 36/300
#  - 1s - loss: 0.0381 - accuracy: 0.9854 - val_loss: 0.4773 - val_accuracy: 0.8714
# Epoch 37/300
#  - 1s - loss: 0.0395 - accuracy: 0.9849 - val_loss: 0.5594 - val_accuracy: 0.8619
# Epoch 38/300
#  - 1s - loss: 0.0411 - accuracy: 0.9815 - val_loss: 0.6109 - val_accuracy: 0.8571
# Epoch 39/300
#  - 1s - loss: 0.0421 - accuracy: 0.9854 - val_loss: 0.5834 - val_accuracy: 0.8667
# Epoch 40/300
#  - 1s - loss: 0.0243 - accuracy: 0.9950 - val_loss: 0.5636 - val_accuracy: 0.8762
# Epoch 41/300
#  - 1s - loss: 0.0268 - accuracy: 0.9894 - val_loss: 0.4920 - val_accuracy: 0.8857
# Epoch 42/300
#  - 1s - loss: 0.0341 - accuracy: 0.9888 - val_loss: 0.5478 - val_accuracy: 0.8762
# Epoch 43/300
#  - 1s - loss: 0.0359 - accuracy: 0.9894 - val_loss: 0.6580 - val_accuracy: 0.8714
# Epoch 44/300
#  - 1s - loss: 0.0287 - accuracy: 0.9888 - val_loss: 0.5154 - val_accuracy: 0.8714
# Epoch 45/300
#  - 1s - loss: 0.0212 - accuracy: 0.9922 - val_loss: 0.5856 - val_accuracy: 0.8905
# Epoch 46/300
#  - 1s - loss: 0.0314 - accuracy: 0.9882 - val_loss: 0.6441 - val_accuracy: 0.8714
# Epoch 47/300
#  - 1s - loss: 0.0216 - accuracy: 0.9933 - val_loss: 0.6429 - val_accuracy: 0.8810
# Epoch 48/300
#  - 1s - loss: 0.0176 - accuracy: 0.9944 - val_loss: 0.5095 - val_accuracy: 0.8905
# Epoch 49/300
#  - 1s - loss: 0.0161 - accuracy: 0.9944 - val_loss: 0.5291 - val_accuracy: 0.8762
# Epoch 50/300
#  - 1s - loss: 0.0225 - accuracy: 0.9927 - val_loss: 0.5631 - val_accuracy: 0.8810
# Epoch 51/300
#  - 1s - loss: 0.0317 - accuracy: 0.9894 - val_loss: 0.5305 - val_accuracy: 0.8762
# Epoch 52/300
#  - 1s - loss: 0.0352 - accuracy: 0.9877 - val_loss: 0.4785 - val_accuracy: 0.8810
# Epoch 53/300
#  - 1s - loss: 0.0262 - accuracy: 0.9899 - val_loss: 0.5031 - val_accuracy: 0.8952
# Epoch 54/300
#  - 1s - loss: 0.0274 - accuracy: 0.9910 - val_loss: 0.5366 - val_accuracy: 0.8857
# Epoch 55/300
#  - 1s - loss: 0.0151 - accuracy: 0.9972 - val_loss: 0.5800 - val_accuracy: 0.8810
# Epoch 56/300
#  - 1s - loss: 0.0143 - accuracy: 0.9972 - val_loss: 0.6968 - val_accuracy: 0.8667
# Epoch 57/300
#  - 1s - loss: 0.0194 - accuracy: 0.9944 - val_loss: 0.6208 - val_accuracy: 0.8810
# Epoch 58/300
#  - 1s - loss: 0.0164 - accuracy: 0.9938 - val_loss: 0.6587 - val_accuracy: 0.9000
# Epoch 59/300
#  - 1s - loss: 0.0281 - accuracy: 0.9905 - val_loss: 0.5627 - val_accuracy: 0.8667
# Epoch 60/300
#  - 1s - loss: 0.0202 - accuracy: 0.9938 - val_loss: 0.5289 - val_accuracy: 0.8762
# Epoch 61/300
#  - 1s - loss: 0.0298 - accuracy: 0.9899 - val_loss: 0.5171 - val_accuracy: 0.8667
# Epoch 62/300
#  - 1s - loss: 0.0312 - accuracy: 0.9888 - val_loss: 0.5317 - val_accuracy: 0.8952
# Epoch 63/300
#  - 1s - loss: 0.0249 - accuracy: 0.9922 - val_loss: 0.4907 - val_accuracy: 0.8762
# Epoch 64/300
#  - 1s - loss: 0.0261 - accuracy: 0.9916 - val_loss: 0.6059 - val_accuracy: 0.8762
# Epoch 65/300
#  - 1s - loss: 0.0321 - accuracy: 0.9894 - val_loss: 0.5483 - val_accuracy: 0.8619
# Epoch 66/300
#  - 1s - loss: 0.0216 - accuracy: 0.9916 - val_loss: 0.4896 - val_accuracy: 0.8619
# Epoch 67/300
#  - 1s - loss: 0.0288 - accuracy: 0.9899 - val_loss: 0.4861 - val_accuracy: 0.8857
# Epoch 68/300
#  - 1s - loss: 0.0289 - accuracy: 0.9905 - val_loss: 0.5200 - val_accuracy: 0.8857
# Epoch 69/300
#  - 1s - loss: 0.0498 - accuracy: 0.9826 - val_loss: 0.5150 - val_accuracy: 0.8714
# Epoch 70/300
#  - 1s - loss: 0.0240 - accuracy: 0.9927 - val_loss: 0.5957 - val_accuracy: 0.8714
# Epoch 71/300
#  - 1s - loss: 0.0407 - accuracy: 0.9854 - val_loss: 0.5669 - val_accuracy: 0.8857
# Epoch 72/300
#  - 1s - loss: 0.0358 - accuracy: 0.9866 - val_loss: 0.5672 - val_accuracy: 0.8810
# Epoch 73/300
#  - 1s - loss: 0.0341 - accuracy: 0.9882 - val_loss: 0.6109 - val_accuracy: 0.9048
# Epoch 74/300
#  - 1s - loss: 0.0122 - accuracy: 0.9966 - val_loss: 0.5443 - val_accuracy: 0.8619
# Epoch 75/300
#  - 1s - loss: 0.0220 - accuracy: 0.9933 - val_loss: 0.6590 - val_accuracy: 0.8857
# Epoch 76/300
#  - 1s - loss: 0.0489 - accuracy: 0.9849 - val_loss: 0.6140 - val_accuracy: 0.8905
# Epoch 77/300
#  - 1s - loss: 0.0532 - accuracy: 0.9860 - val_loss: 0.6704 - val_accuracy: 0.8762
# Epoch 78/300
#  - 1s - loss: 0.0298 - accuracy: 0.9899 - val_loss: 0.6345 - val_accuracy: 0.8810
# Epoch 79/300
#  - 1s - loss: 0.0253 - accuracy: 0.9916 - val_loss: 0.5920 - val_accuracy: 0.8857
# Epoch 80/300
#  - 1s - loss: 0.0259 - accuracy: 0.9905 - val_loss: 0.7414 - val_accuracy: 0.8905
# Epoch 81/300
#  - 1s - loss: 0.0511 - accuracy: 0.9866 - val_loss: 0.7811 - val_accuracy: 0.8619
# Epoch 82/300
#  - 1s - loss: 0.0416 - accuracy: 0.9854 - val_loss: 0.5139 - val_accuracy: 0.8952
# Epoch 83/300
#  - 1s - loss: 0.0531 - accuracy: 0.9826 - val_loss: 0.6616 - val_accuracy: 0.8762
# Epoch 84/300
#  - 1s - loss: 0.0561 - accuracy: 0.9776 - val_loss: 0.7225 - val_accuracy: 0.8429
# Epoch 85/300
#  - 1s - loss: 0.0716 - accuracy: 0.9770 - val_loss: 0.7338 - val_accuracy: 0.8762
# Epoch 86/300
#  - 1s - loss: 0.0741 - accuracy: 0.9703 - val_loss: 0.6620 - val_accuracy: 0.8667
# Epoch 87/300
#  - 1s - loss: 0.0570 - accuracy: 0.9826 - val_loss: 0.6147 - val_accuracy: 0.8762
# Epoch 88/300
#  - 1s - loss: 0.0794 - accuracy: 0.9731 - val_loss: 0.5702 - val_accuracy: 0.8714
# Epoch 89/300
#  - 1s - loss: 0.0558 - accuracy: 0.9804 - val_loss: 0.4989 - val_accuracy: 0.8762
# Epoch 90/300
#  - 1s - loss: 0.0283 - accuracy: 0.9916 - val_loss: 0.4891 - val_accuracy: 0.8857
# Epoch 91/300
#  - 1s - loss: 0.0274 - accuracy: 0.9894 - val_loss: 0.5835 - val_accuracy: 0.8714
# Epoch 92/300
#  - 1s - loss: 0.0392 - accuracy: 0.9849 - val_loss: 0.6011 - val_accuracy: 0.8905
# Epoch 93/300
#  - 1s - loss: 0.0296 - accuracy: 0.9877 - val_loss: 0.4703 - val_accuracy: 0.8571
# Epoch 94/300
#  - 1s - loss: 0.0292 - accuracy: 0.9871 - val_loss: 0.6944 - val_accuracy: 0.9000
# Epoch 95/300
#  - 1s - loss: 0.0415 - accuracy: 0.9894 - val_loss: 0.5781 - val_accuracy: 0.8667
# Epoch 96/300
#  - 1s - loss: 0.0247 - accuracy: 0.9922 - val_loss: 0.6414 - val_accuracy: 0.8524
# Epoch 97/300
#  - 1s - loss: 0.0260 - accuracy: 0.9905 - val_loss: 0.5895 - val_accuracy: 0.8810
# Epoch 98/300
#  - 1s - loss: 0.0316 - accuracy: 0.9894 - val_loss: 0.7673 - val_accuracy: 0.8571
# Epoch 99/300
#  - 1s - loss: 0.0248 - accuracy: 0.9894 - val_loss: 0.7260 - val_accuracy: 0.8857
# Epoch 100/300
#  - 1s - loss: 0.0163 - accuracy: 0.9927 - val_loss: 0.6516 - val_accuracy: 0.8714
# Epoch 101/300
#  - 1s - loss: 0.0174 - accuracy: 0.9927 - val_loss: 0.6490 - val_accuracy: 0.8857
# Epoch 102/300
#  - 1s - loss: 0.0190 - accuracy: 0.9933 - val_loss: 0.7874 - val_accuracy: 0.8667
# Epoch 103/300
#  - 1s - loss: 0.0268 - accuracy: 0.9899 - val_loss: 0.7002 - val_accuracy: 0.8667
# Epoch 104/300
#  - 1s - loss: 0.0196 - accuracy: 0.9933 - val_loss: 0.6490 - val_accuracy: 0.8952
# Epoch 105/300
#  - 1s - loss: 0.0174 - accuracy: 0.9944 - val_loss: 0.6211 - val_accuracy: 0.9000
# Epoch 106/300
#  - 1s - loss: 0.0200 - accuracy: 0.9916 - val_loss: 0.6649 - val_accuracy: 0.8810
# Epoch 107/300
#  - 1s - loss: 0.0234 - accuracy: 0.9894 - val_loss: 0.6940 - val_accuracy: 0.8667
# Epoch 108/300
#  - 1s - loss: 0.0278 - accuracy: 0.9899 - val_loss: 0.7701 - val_accuracy: 0.8810
# Epoch 109/300
#  - 1s - loss: 0.0233 - accuracy: 0.9938 - val_loss: 0.6043 - val_accuracy: 0.8905
# Epoch 110/300
#  - 1s - loss: 0.0244 - accuracy: 0.9916 - val_loss: 0.6596 - val_accuracy: 0.8857
# Epoch 111/300
#  - 1s - loss: 0.0081 - accuracy: 0.9978 - val_loss: 0.7379 - val_accuracy: 0.8857
# Epoch 112/300
#  - 1s - loss: 0.0260 - accuracy: 0.9933 - val_loss: 0.6987 - val_accuracy: 0.8667
# Epoch 113/300
#  - 1s - loss: 0.0232 - accuracy: 0.9922 - val_loss: 0.7540 - val_accuracy: 0.8714
# Epoch 114/300
#  - 1s - loss: 0.0245 - accuracy: 0.9905 - val_loss: 0.9024 - val_accuracy: 0.8762
# Epoch 115/300
#  - 1s - loss: 0.0232 - accuracy: 0.9910 - val_loss: 0.8102 - val_accuracy: 0.8524
# Epoch 116/300
#  - 1s - loss: 0.0317 - accuracy: 0.9910 - val_loss: 0.5579 - val_accuracy: 0.9048
# Epoch 117/300
#  - 1s - loss: 0.0263 - accuracy: 0.9927 - val_loss: 0.6162 - val_accuracy: 0.8762
# Epoch 118/300
#  - 1s - loss: 0.0356 - accuracy: 0.9877 - val_loss: 0.6792 - val_accuracy: 0.8905
# Epoch 119/300
#  - 1s - loss: 0.0169 - accuracy: 0.9933 - val_loss: 0.9814 - val_accuracy: 0.8810
# Epoch 120/300
#  - 1s - loss: 0.0259 - accuracy: 0.9933 - val_loss: 0.7326 - val_accuracy: 0.8857
# Epoch 121/300
#  - 1s - loss: 0.0175 - accuracy: 0.9944 - val_loss: 0.8360 - val_accuracy: 0.8762
# Epoch 122/300
#  - 1s - loss: 0.0148 - accuracy: 0.9955 - val_loss: 0.7759 - val_accuracy: 0.8905
# Epoch 123/300
#  - 1s - loss: 0.0165 - accuracy: 0.9933 - val_loss: 0.9106 - val_accuracy: 0.8952
# Epoch 124/300
#  - 1s - loss: 0.0304 - accuracy: 0.9894 - val_loss: 0.7484 - val_accuracy: 0.8905
# Epoch 125/300
#  - 1s - loss: 0.0238 - accuracy: 0.9922 - val_loss: 0.6547 - val_accuracy: 0.8762
# Epoch 126/300
#  - 1s - loss: 0.0272 - accuracy: 0.9899 - val_loss: 0.8160 - val_accuracy: 0.8952
# Epoch 127/300
#  - 1s - loss: 0.0379 - accuracy: 0.9899 - val_loss: 0.7403 - val_accuracy: 0.8857
# Epoch 128/300
#  - 1s - loss: 0.0210 - accuracy: 0.9927 - val_loss: 0.6189 - val_accuracy: 0.8810
# Epoch 129/300
#  - 1s - loss: 0.0131 - accuracy: 0.9922 - val_loss: 0.6553 - val_accuracy: 0.9000
# Epoch 130/300
#  - 1s - loss: 0.0222 - accuracy: 0.9938 - val_loss: 0.6913 - val_accuracy: 0.8905
# Epoch 131/300
#  - 1s - loss: 0.0178 - accuracy: 0.9927 - val_loss: 0.8596 - val_accuracy: 0.8619
# Epoch 132/300
#  - 1s - loss: 0.0158 - accuracy: 0.9950 - val_loss: 0.8472 - val_accuracy: 0.8810
# Epoch 133/300
#  - 1s - loss: 0.0153 - accuracy: 0.9961 - val_loss: 0.7611 - val_accuracy: 0.9048
# Epoch 134/300
#  - 1s - loss: 0.0243 - accuracy: 0.9899 - val_loss: 0.7547 - val_accuracy: 0.8857
# Epoch 135/300
#  - 1s - loss: 0.0305 - accuracy: 0.9910 - val_loss: 0.6832 - val_accuracy: 0.8762
# Epoch 136/300
#  - 1s - loss: 0.0225 - accuracy: 0.9922 - val_loss: 0.8623 - val_accuracy: 0.8905
# Epoch 137/300
#  - 1s - loss: 0.0374 - accuracy: 0.9905 - val_loss: 0.6814 - val_accuracy: 0.8905
# Epoch 138/300
#  - 1s - loss: 0.0205 - accuracy: 0.9938 - val_loss: 0.6042 - val_accuracy: 0.9000
# Epoch 139/300
#  - 1s - loss: 0.0278 - accuracy: 0.9916 - val_loss: 0.6729 - val_accuracy: 0.8619
# Epoch 140/300
#  - 1s - loss: 0.0186 - accuracy: 0.9922 - val_loss: 0.6471 - val_accuracy: 0.8952
# Epoch 141/300
#  - 1s - loss: 0.0215 - accuracy: 0.9933 - val_loss: 0.7285 - val_accuracy: 0.8714
# Epoch 142/300
#  - 1s - loss: 0.0500 - accuracy: 0.9843 - val_loss: 0.8862 - val_accuracy: 0.8667
# Epoch 143/300
#  - 1s - loss: 0.0328 - accuracy: 0.9854 - val_loss: 0.7638 - val_accuracy: 0.8619
# Epoch 144/300
#  - 1s - loss: 0.0323 - accuracy: 0.9899 - val_loss: 0.8266 - val_accuracy: 0.8905
# Epoch 145/300
#  - 1s - loss: 0.0290 - accuracy: 0.9910 - val_loss: 0.7520 - val_accuracy: 0.8857
# Epoch 146/300
#  - 1s - loss: 0.0399 - accuracy: 0.9854 - val_loss: 0.8997 - val_accuracy: 0.8762
# Epoch 147/300
#  - 1s - loss: 0.0460 - accuracy: 0.9860 - val_loss: 0.8253 - val_accuracy: 0.8762
# Epoch 148/300
#  - 1s - loss: 0.0266 - accuracy: 0.9894 - val_loss: 0.7498 - val_accuracy: 0.8810
# Epoch 149/300
#  - 1s - loss: 0.0165 - accuracy: 0.9922 - val_loss: 0.9628 - val_accuracy: 0.8810
# Epoch 150/300
#  - 1s - loss: 0.0193 - accuracy: 0.9938 - val_loss: 0.6990 - val_accuracy: 0.8810
# Epoch 151/300
#  - 1s - loss: 0.0128 - accuracy: 0.9944 - val_loss: 1.0063 - val_accuracy: 0.8762
# Epoch 152/300
#  - 1s - loss: 0.0184 - accuracy: 0.9944 - val_loss: 0.6864 - val_accuracy: 0.9190
# Epoch 153/300
#  - 1s - loss: 0.0357 - accuracy: 0.9899 - val_loss: 0.5909 - val_accuracy: 0.8952
# Epoch 154/300
#  - 1s - loss: 0.0459 - accuracy: 0.9860 - val_loss: 0.9435 - val_accuracy: 0.8619
# Epoch 155/300
#  - 1s - loss: 0.0193 - accuracy: 0.9933 - val_loss: 0.7463 - val_accuracy: 0.8857
# Epoch 156/300
#  - 1s - loss: 0.0081 - accuracy: 0.9950 - val_loss: 0.7292 - val_accuracy: 0.9000
# Epoch 157/300
#  - 1s - loss: 0.0122 - accuracy: 0.9972 - val_loss: 0.7158 - val_accuracy: 0.9000
# Epoch 158/300
#  - 1s - loss: 0.0185 - accuracy: 0.9938 - val_loss: 0.7928 - val_accuracy: 0.8857
# Epoch 159/300
#  - 1s - loss: 0.0204 - accuracy: 0.9922 - val_loss: 0.8073 - val_accuracy: 0.8952
# Epoch 160/300
#  - 1s - loss: 0.0159 - accuracy: 0.9944 - val_loss: 0.7656 - val_accuracy: 0.9095
# Epoch 161/300
#  - 1s - loss: 0.0279 - accuracy: 0.9916 - val_loss: 0.7471 - val_accuracy: 0.8381
# Epoch 162/300
#  - 1s - loss: 0.0316 - accuracy: 0.9894 - val_loss: 0.7067 - val_accuracy: 0.8714
# Epoch 163/300
#  - 1s - loss: 0.0227 - accuracy: 0.9933 - val_loss: 0.7760 - val_accuracy: 0.8476
# Epoch 164/300
#  - 1s - loss: 0.0286 - accuracy: 0.9888 - val_loss: 0.8233 - val_accuracy: 0.8714
# Epoch 165/300
#  - 1s - loss: 0.0237 - accuracy: 0.9916 - val_loss: 1.0519 - val_accuracy: 0.8905
# Epoch 166/300
#  - 1s - loss: 0.0271 - accuracy: 0.9922 - val_loss: 0.7114 - val_accuracy: 0.8762
# Epoch 167/300
#  - 1s - loss: 0.0173 - accuracy: 0.9933 - val_loss: 0.7369 - val_accuracy: 0.8810
# Epoch 168/300
#  - 1s - loss: 0.0273 - accuracy: 0.9922 - val_loss: 0.9513 - val_accuracy: 0.9095
# Epoch 169/300
#  - 1s - loss: 0.0195 - accuracy: 0.9944 - val_loss: 0.8335 - val_accuracy: 0.8762
# Epoch 170/300
#  - 1s - loss: 0.0150 - accuracy: 0.9950 - val_loss: 0.7677 - val_accuracy: 0.8762
# Epoch 171/300
#  - 1s - loss: 0.0184 - accuracy: 0.9910 - val_loss: 0.8383 - val_accuracy: 0.8762
# Epoch 172/300
#  - 1s - loss: 0.0212 - accuracy: 0.9944 - val_loss: 0.9273 - val_accuracy: 0.8714
# Epoch 173/300
#  - 1s - loss: 0.0123 - accuracy: 0.9950 - val_loss: 0.8784 - val_accuracy: 0.8762
# Epoch 174/300
#  - 1s - loss: 0.0224 - accuracy: 0.9938 - val_loss: 0.8133 - val_accuracy: 0.8810
# Epoch 175/300
#  - 1s - loss: 0.0255 - accuracy: 0.9910 - val_loss: 0.7069 - val_accuracy: 0.9095
# Epoch 176/300
#  - 1s - loss: 0.0162 - accuracy: 0.9961 - val_loss: 0.8649 - val_accuracy: 0.8667
# Epoch 177/300
#  - 1s - loss: 0.0297 - accuracy: 0.9933 - val_loss: 1.0890 - val_accuracy: 0.8905
# Epoch 178/300
#  - 1s - loss: 0.0188 - accuracy: 0.9927 - val_loss: 0.8870 - val_accuracy: 0.8714
# Epoch 179/300
#  - 1s - loss: 0.0135 - accuracy: 0.9961 - val_loss: 1.0589 - val_accuracy: 0.8619
# Epoch 180/300
#  - 1s - loss: 0.0221 - accuracy: 0.9927 - val_loss: 0.9133 - val_accuracy: 0.8857
# Epoch 181/300
#  - 1s - loss: 0.0271 - accuracy: 0.9922 - val_loss: 1.1503 - val_accuracy: 0.8762
# Epoch 182/300
#  - 1s - loss: 0.0472 - accuracy: 0.9905 - val_loss: 0.7507 - val_accuracy: 0.8905
# Epoch 183/300
#  - 1s - loss: 0.0164 - accuracy: 0.9950 - val_loss: 0.7685 - val_accuracy: 0.8714
# Epoch 184/300
#  - 1s - loss: 0.0148 - accuracy: 0.9966 - val_loss: 0.9054 - val_accuracy: 0.8810
# Epoch 185/300
#  - 1s - loss: 0.0189 - accuracy: 0.9933 - val_loss: 1.0132 - val_accuracy: 0.8571
# Epoch 186/300
#  - 1s - loss: 0.0206 - accuracy: 0.9927 - val_loss: 0.8810 - val_accuracy: 0.8667
# Epoch 187/300
#  - 1s - loss: 0.0199 - accuracy: 0.9933 - val_loss: 0.9718 - val_accuracy: 0.8524
# Epoch 188/300
#  - 1s - loss: 0.0203 - accuracy: 0.9950 - val_loss: 0.7061 - val_accuracy: 0.8810
# Epoch 189/300
#  - 1s - loss: 0.0071 - accuracy: 0.9978 - val_loss: 0.7138 - val_accuracy: 0.8762
# Epoch 190/300
#  - 1s - loss: 0.0144 - accuracy: 0.9944 - val_loss: 0.9772 - val_accuracy: 0.8571
# Epoch 191/300
#  - 1s - loss: 0.0132 - accuracy: 0.9927 - val_loss: 0.8793 - val_accuracy: 0.8857
# Epoch 192/300
#  - 1s - loss: 0.0140 - accuracy: 0.9944 - val_loss: 0.9328 - val_accuracy: 0.8714
# Epoch 193/300
#  - 1s - loss: 0.0251 - accuracy: 0.9922 - val_loss: 0.8289 - val_accuracy: 0.9000
# Epoch 194/300
#  - 1s - loss: 0.0230 - accuracy: 0.9910 - val_loss: 0.9326 - val_accuracy: 0.8714
# Epoch 195/300
#  - 1s - loss: 0.0260 - accuracy: 0.9922 - val_loss: 0.9056 - val_accuracy: 0.8857
# Epoch 196/300
#  - 1s - loss: 0.0238 - accuracy: 0.9916 - val_loss: 0.9680 - val_accuracy: 0.8667
# Epoch 197/300
#  - 1s - loss: 0.0173 - accuracy: 0.9944 - val_loss: 0.8608 - val_accuracy: 0.8762
# Epoch 198/300
#  - 1s - loss: 0.0241 - accuracy: 0.9894 - val_loss: 1.0421 - val_accuracy: 0.8857
# Epoch 199/300
#  - 1s - loss: 0.0298 - accuracy: 0.9927 - val_loss: 0.9963 - val_accuracy: 0.8905
# Epoch 200/300
#  - 1s - loss: 0.0239 - accuracy: 0.9944 - val_loss: 0.7577 - val_accuracy: 0.8762
# Epoch 201/300
#  - 1s - loss: 0.0164 - accuracy: 0.9955 - val_loss: 1.0295 - val_accuracy: 0.8857
# Epoch 202/300
#  - 1s - loss: 0.0182 - accuracy: 0.9944 - val_loss: 0.8852 - val_accuracy: 0.8905
# Epoch 203/300
#  - 1s - loss: 0.0127 - accuracy: 0.9950 - val_loss: 0.9603 - val_accuracy: 0.8952
# Epoch 204/300
#  - 1s - loss: 0.0233 - accuracy: 0.9933 - val_loss: 0.8885 - val_accuracy: 0.8857
# Epoch 205/300
#  - 1s - loss: 0.0350 - accuracy: 0.9894 - val_loss: 0.8811 - val_accuracy: 0.8810
# Epoch 206/300
#  - 1s - loss: 0.0182 - accuracy: 0.9933 - val_loss: 0.8508 - val_accuracy: 0.8905
# Epoch 207/300
#  - 1s - loss: 0.0181 - accuracy: 0.9966 - val_loss: 1.0020 - val_accuracy: 0.8905
# Epoch 208/300
#  - 1s - loss: 0.0193 - accuracy: 0.9944 - val_loss: 1.0169 - val_accuracy: 0.8762
# Epoch 209/300
#  - 1s - loss: 0.0111 - accuracy: 0.9955 - val_loss: 1.2434 - val_accuracy: 0.8667
# Epoch 210/300
#  - 1s - loss: 0.0175 - accuracy: 0.9961 - val_loss: 0.9691 - val_accuracy: 0.8810
# Epoch 211/300
#  - 1s - loss: 0.0171 - accuracy: 0.9922 - val_loss: 1.0613 - val_accuracy: 0.8619
# Epoch 212/300
#  - 1s - loss: 0.0301 - accuracy: 0.9933 - val_loss: 1.0353 - val_accuracy: 0.8571
# Epoch 213/300
#  - 1s - loss: 0.0172 - accuracy: 0.9950 - val_loss: 0.8185 - val_accuracy: 0.8667
# Epoch 214/300
#  - 1s - loss: 0.0257 - accuracy: 0.9933 - val_loss: 1.0791 - val_accuracy: 0.8762
# Epoch 215/300
#  - 1s - loss: 0.0233 - accuracy: 0.9944 - val_loss: 0.6833 - val_accuracy: 0.8952
# Epoch 216/300
#  - 1s - loss: 0.0144 - accuracy: 0.9955 - val_loss: 0.8213 - val_accuracy: 0.8762
# Epoch 217/300
#  - 1s - loss: 0.0156 - accuracy: 0.9950 - val_loss: 0.8759 - val_accuracy: 0.8952
# Epoch 218/300
#  - 1s - loss: 0.0278 - accuracy: 0.9933 - val_loss: 0.9678 - val_accuracy: 0.8762
# Epoch 219/300
#  - 1s - loss: 0.0288 - accuracy: 0.9905 - val_loss: 1.0908 - val_accuracy: 0.8857
# Epoch 220/300
#  - 1s - loss: 0.0237 - accuracy: 0.9905 - val_loss: 0.8290 - val_accuracy: 0.8857
# Epoch 221/300
#  - 1s - loss: 0.0154 - accuracy: 0.9955 - val_loss: 0.8282 - val_accuracy: 0.8857
# Epoch 222/300
#  - 1s - loss: 0.0274 - accuracy: 0.9905 - val_loss: 1.0874 - val_accuracy: 0.8667
# Epoch 223/300
#  - 1s - loss: 0.0118 - accuracy: 0.9955 - val_loss: 0.9495 - val_accuracy: 0.8905
# Epoch 224/300
#  - 1s - loss: 0.0142 - accuracy: 0.9950 - val_loss: 0.8718 - val_accuracy: 0.8952
# Epoch 225/300
#  - 1s - loss: 0.0191 - accuracy: 0.9961 - val_loss: 1.1898 - val_accuracy: 0.8619
# Epoch 226/300
#  - 1s - loss: 0.0226 - accuracy: 0.9922 - val_loss: 0.8482 - val_accuracy: 0.8667
# Epoch 227/300
#  - 1s - loss: 0.0167 - accuracy: 0.9955 - val_loss: 1.1429 - val_accuracy: 0.8810
# Epoch 228/300
#  - 1s - loss: 0.0238 - accuracy: 0.9933 - val_loss: 0.9678 - val_accuracy: 0.8762
# Epoch 229/300
#  - 1s - loss: 0.0267 - accuracy: 0.9922 - val_loss: 1.1325 - val_accuracy: 0.8667
# Epoch 230/300
#  - 1s - loss: 0.0224 - accuracy: 0.9933 - val_loss: 1.0729 - val_accuracy: 0.8524
# Epoch 231/300
#  - 1s - loss: 0.0213 - accuracy: 0.9938 - val_loss: 0.9363 - val_accuracy: 0.8476
# Epoch 232/300
#  - 1s - loss: 0.0182 - accuracy: 0.9944 - val_loss: 1.0103 - val_accuracy: 0.8810
# Epoch 233/300
#  - 1s - loss: 0.0260 - accuracy: 0.9938 - val_loss: 1.0498 - val_accuracy: 0.8952
# Epoch 234/300
#  - 1s - loss: 0.0172 - accuracy: 0.9950 - val_loss: 1.1593 - val_accuracy: 0.8905
# Epoch 235/300
#  - 1s - loss: 0.0306 - accuracy: 0.9933 - val_loss: 0.9836 - val_accuracy: 0.8905
# Epoch 236/300
#  - 1s - loss: 0.0188 - accuracy: 0.9950 - val_loss: 1.2014 - val_accuracy: 0.9048
# Epoch 237/300
#  - 1s - loss: 0.0204 - accuracy: 0.9944 - val_loss: 1.2071 - val_accuracy: 0.8905
# Epoch 238/300
#  - 1s - loss: 0.0233 - accuracy: 0.9927 - val_loss: 1.1413 - val_accuracy: 0.8714
# Epoch 239/300
#  - 1s - loss: 0.0337 - accuracy: 0.9888 - val_loss: 0.9596 - val_accuracy: 0.8952
# Epoch 240/300
#  - 1s - loss: 0.0485 - accuracy: 0.9882 - val_loss: 1.2215 - val_accuracy: 0.8667
# Epoch 241/300
#  - 1s - loss: 0.0166 - accuracy: 0.9933 - val_loss: 0.9028 - val_accuracy: 0.9048
# Epoch 242/300
#  - 1s - loss: 0.0197 - accuracy: 0.9916 - val_loss: 0.9746 - val_accuracy: 0.8905
# Epoch 243/300
#  - 1s - loss: 0.0155 - accuracy: 0.9950 - val_loss: 1.0970 - val_accuracy: 0.8952
# Epoch 244/300
#  - 1s - loss: 0.0163 - accuracy: 0.9972 - val_loss: 0.8951 - val_accuracy: 0.9095
# Epoch 245/300
#  - 1s - loss: 0.0151 - accuracy: 0.9944 - val_loss: 0.9555 - val_accuracy: 0.9000
# Epoch 246/300
#  - 1s - loss: 0.0097 - accuracy: 0.9978 - val_loss: 1.1439 - val_accuracy: 0.8762
# Epoch 247/300
#  - 1s - loss: 0.0029 - accuracy: 0.9989 - val_loss: 1.0861 - val_accuracy: 0.8714
# Epoch 248/300
#  - 1s - loss: 0.0104 - accuracy: 0.9955 - val_loss: 1.3738 - val_accuracy: 0.8714
# Epoch 249/300
#  - 1s - loss: 0.0151 - accuracy: 0.9944 - val_loss: 1.2994 - val_accuracy: 0.9000
# Epoch 250/300
#  - 1s - loss: 0.0300 - accuracy: 0.9916 - val_loss: 1.1194 - val_accuracy: 0.8571
# Epoch 251/300
#  - 1s - loss: 0.0285 - accuracy: 0.9933 - val_loss: 1.0697 - val_accuracy: 0.8762
# Epoch 252/300
#  - 1s - loss: 0.0293 - accuracy: 0.9927 - val_loss: 1.4297 - val_accuracy: 0.8905
# Epoch 253/300
#  - 1s - loss: 0.0373 - accuracy: 0.9916 - val_loss: 1.2339 - val_accuracy: 0.8714
# Epoch 254/300
#  - 1s - loss: 0.0446 - accuracy: 0.9888 - val_loss: 1.3080 - val_accuracy: 0.8619
# Epoch 255/300
#  - 1s - loss: 0.0297 - accuracy: 0.9922 - val_loss: 0.9385 - val_accuracy: 0.8571
# Epoch 256/300
#  - 1s - loss: 0.0149 - accuracy: 0.9955 - val_loss: 0.9161 - val_accuracy: 0.8762
# Epoch 257/300
#  - 1s - loss: 0.0324 - accuracy: 0.9894 - val_loss: 1.0130 - val_accuracy: 0.8714
# Epoch 258/300
#  - 1s - loss: 0.0283 - accuracy: 0.9927 - val_loss: 1.2156 - val_accuracy: 0.8619
# Epoch 259/300
#  - 1s - loss: 0.0300 - accuracy: 0.9916 - val_loss: 0.9748 - val_accuracy: 0.8810
# Epoch 260/300
#  - 1s - loss: 0.0483 - accuracy: 0.9866 - val_loss: 0.9786 - val_accuracy: 0.8810
# Epoch 261/300
#  - 1s - loss: 0.0479 - accuracy: 0.9877 - val_loss: 0.9075 - val_accuracy: 0.8857
# Epoch 262/300
#  - 1s - loss: 0.0232 - accuracy: 0.9922 - val_loss: 0.8244 - val_accuracy: 0.8714
# Epoch 263/300
#  - 1s - loss: 0.0170 - accuracy: 0.9972 - val_loss: 0.9584 - val_accuracy: 0.8619
# Epoch 264/300
#  - 1s - loss: 0.0146 - accuracy: 0.9950 - val_loss: 1.0069 - val_accuracy: 0.8667
# Epoch 265/300
#  - 1s - loss: 0.0082 - accuracy: 0.9972 - val_loss: 1.0190 - val_accuracy: 0.8810
# Epoch 266/300
#  - 1s - loss: 0.0171 - accuracy: 0.9933 - val_loss: 1.1215 - val_accuracy: 0.8714
# Epoch 267/300
#  - 1s - loss: 0.0225 - accuracy: 0.9933 - val_loss: 1.0951 - val_accuracy: 0.8571
# Epoch 268/300
#  - 1s - loss: 0.0327 - accuracy: 0.9927 - val_loss: 1.3040 - val_accuracy: 0.8667
# Epoch 269/300
#  - 1s - loss: 0.0108 - accuracy: 0.9966 - val_loss: 1.1406 - val_accuracy: 0.8810
# Epoch 270/300
#  - 1s - loss: 0.0216 - accuracy: 0.9950 - val_loss: 0.9353 - val_accuracy: 0.8857
# Epoch 271/300
#  - 1s - loss: 0.0244 - accuracy: 0.9922 - val_loss: 1.0054 - val_accuracy: 0.8667
# Epoch 272/300
#  - 1s - loss: 0.0105 - accuracy: 0.9966 - val_loss: 1.1174 - val_accuracy: 0.8762
# Epoch 273/300
#  - 1s - loss: 0.0339 - accuracy: 0.9910 - val_loss: 0.9180 - val_accuracy: 0.8714
# Epoch 274/300
#  - 1s - loss: 0.0155 - accuracy: 0.9955 - val_loss: 0.8490 - val_accuracy: 0.8857
# Epoch 275/300
#  - 1s - loss: 0.0120 - accuracy: 0.9978 - val_loss: 0.9462 - val_accuracy: 0.8905
# Epoch 276/300
#  - 1s - loss: 0.0145 - accuracy: 0.9955 - val_loss: 1.0109 - val_accuracy: 0.9000
# Epoch 277/300
#  - 1s - loss: 0.0162 - accuracy: 0.9955 - val_loss: 0.9495 - val_accuracy: 0.8571
# Epoch 278/300
#  - 1s - loss: 0.0102 - accuracy: 0.9966 - val_loss: 0.8304 - val_accuracy: 0.8810
# Epoch 279/300
#  - 1s - loss: 0.0120 - accuracy: 0.9950 - val_loss: 1.0785 - val_accuracy: 0.8714
# Epoch 280/300
#  - 1s - loss: 0.0213 - accuracy: 0.9972 - val_loss: 0.9879 - val_accuracy: 0.8714
# Epoch 281/300
#  - 1s - loss: 0.0163 - accuracy: 0.9950 - val_loss: 1.2253 - val_accuracy: 0.8667
# Epoch 282/300
#  - 1s - loss: 0.0122 - accuracy: 0.9950 - val_loss: 1.0275 - val_accuracy: 0.8952
# Epoch 283/300
#  - 1s - loss: 0.0117 - accuracy: 0.9972 - val_loss: 1.1256 - val_accuracy: 0.8667
# Epoch 284/300
#  - 1s - loss: 0.0066 - accuracy: 0.9966 - val_loss: 0.9764 - val_accuracy: 0.8857
# Epoch 285/300
#  - 1s - loss: 0.0077 - accuracy: 0.9961 - val_loss: 1.0638 - val_accuracy: 0.8810
# Epoch 286/300
#  - 1s - loss: 0.0038 - accuracy: 0.9989 - val_loss: 0.9861 - val_accuracy: 0.8857
# Epoch 287/300
#  - 1s - loss: 0.0110 - accuracy: 0.9955 - val_loss: 1.0716 - val_accuracy: 0.8810
# Epoch 288/300
#  - 1s - loss: 0.0246 - accuracy: 0.9944 - val_loss: 1.0709 - val_accuracy: 0.8905
# Epoch 289/300
#  - 1s - loss: 0.0261 - accuracy: 0.9955 - val_loss: 1.0238 - val_accuracy: 0.8810
# Epoch 290/300
#  - 1s - loss: 0.0049 - accuracy: 0.9978 - val_loss: 1.1605 - val_accuracy: 0.8667
# Epoch 291/300
#  - 1s - loss: 0.0064 - accuracy: 0.9978 - val_loss: 1.0738 - val_accuracy: 0.8762
# Epoch 292/300
#  - 1s - loss: 0.0212 - accuracy: 0.9955 - val_loss: 1.2494 - val_accuracy: 0.9000
# Epoch 293/300
#  - 1s - loss: 0.0262 - accuracy: 0.9916 - val_loss: 1.0806 - val_accuracy: 0.8619
# Epoch 294/300
#  - 1s - loss: 0.0244 - accuracy: 0.9927 - val_loss: 1.2553 - val_accuracy: 0.8714
# Epoch 295/300
#  - 1s - loss: 0.0210 - accuracy: 0.9938 - val_loss: 1.1966 - val_accuracy: 0.8762
# Epoch 296/300
#  - 1s - loss: 0.0120 - accuracy: 0.9972 - val_loss: 1.1905 - val_accuracy: 0.8810
# Epoch 297/300
#  - 1s - loss: 0.0118 - accuracy: 0.9978 - val_loss: 0.9745 - val_accuracy: 0.8762
# Epoch 298/300
#  - 1s - loss: 0.0387 - accuracy: 0.9916 - val_loss: 0.9013 - val_accuracy: 0.8905
# Epoch 299/300
#  - 1s - loss: 0.0216 - accuracy: 0.9933 - val_loss: 1.4953 - val_accuracy: 0.8714
# Epoch 300/300
#  - 1s - loss: 0.0359 - accuracy: 0.9910 - val_loss: 1.0237 - val_accuracy: 0.8952

# %%
matplotlib.style.use('seaborn')
epochs = len(model_fit_history.history['accuracy'])
plt.axis([0, epochs+1, 0, 1.2])
x = np.arange(1, epochs+1)
plt.plot(x, model_fit_history.history['accuracy'])
plt.plot(x, model_fit_history.history['val_accuracy'])
plt.title('Training accuracy vs. Validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='right')
plt.show()

# %%
matplotlib.style.use('seaborn')
epochs = len(model_fit_history.history['loss'])
max_loss = max(max(model_fit_history.history['loss']), max(model_fit_history.history['val_loss']))
plt.axis([0, epochs+1, 0, round(max_loss * 2.0) / 2 + 0.5])
x = np.arange(1, epochs+1)
plt.plot(x, model_fit_history.history['loss'])
plt.plot(x, model_fit_history.history['val_loss'])
plt.title('Training loss vs. Validation loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='right')
plt.show()

# %%
epochs = np.argmin(model_fit_history.history['val_loss']) + 1
print(f'Stop training at {epochs} epochs')

# Merge training and validation data
X_train = np.concatenate([X['Train'], X['Validation']])
Y_train = np.concatenate([Y['Train'], Y['Validation']])

# Randomly shuffle X and Y
shuffle_index = np.random.permutation(len(X_train))
X_train = X_train[shuffle_index]
Y_train = Y_train[shuffle_index]
model = build_fully_connected(input_shape=X_train.shape[1:], num_classes=num_classes)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
model_fit_history = model.fit(X_train, Y_train, batch_size=64, epochs=epochs, verbose=0)
# Out:
# Stop training at 6 epochs

# %%
y_pred = model.predict_classes(X['Test'], verbose=0)

# %%
y_test = np.nonzero(Y['Test'])[1]
accuracy = accuracy_score(y_test, y_pred)
print(f'Model predication accuracy: {accuracy:.3f}')
print(f'\nClassification report:\n {classification_report(y_test, y_pred)}')
# Out:
# Model predication accuracy: 0.805
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        10
#            1       0.82      0.90      0.86        10
#            2       0.82      0.90      0.86        10
#            3       1.00      1.00      1.00        10
#            4       0.62      0.50      0.56        10
#            5       1.00      0.90      0.95        10
#            6       0.50      0.10      0.17        10
#            7       0.91      1.00      0.95        10
#            8       0.73      0.80      0.76        10
#            9       1.00      0.90      0.95        10
#           10       1.00      0.90      0.95        10
#           11       1.00      0.30      0.46        10
#           12       0.53      0.80      0.64        10
#           13       0.62      0.80      0.70        10
#           14       0.62      0.80      0.70        10
#           15       1.00      1.00      1.00        10
#           16       0.90      0.90      0.90        10
#           17       0.77      1.00      0.87        10
#           18       0.73      0.80      0.76        10
#           19       0.90      0.90      0.90        10
#           20       0.70      0.70      0.70        10
#
#     accuracy                           0.80       210
#    macro avg       0.81      0.80      0.79       210
# weighted avg       0.81      0.80      0.79       210
