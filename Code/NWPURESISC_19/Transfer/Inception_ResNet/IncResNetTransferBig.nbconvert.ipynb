# %%
from contextlib import suppress
import matplotlib
import matplotlib.pyplot as plt

import numpy as np
import os
import warnings

from keras import applications
from keras import optimizers
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, Flatten
from keras.utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import accuracy_score, classification_report
# Out:
# Using TensorFlow backend.

# %%
np.random.seed(8)

# %%
# !pwd
# Out:
# /home/kumarbio/rai00016/Capstone/Code

# %%
class_names = os.listdir('/panfs/roc/groups/14/kumarbio/rai00016/Capstone/Data/NWPURESISC_19/Train/')
target_dirs = {target: '/panfs/roc/groups/14/kumarbio/rai00016/Capstone/Data/NWPURESISC_19/' + target for target in ['Train', 'Validation', 'Test']}

# %%
print(class_names)
print(target_dirs)
# Out:
# ['airplane', 'baseball_diamond', 'beach', 'chaparral', 'dense_residential', 'forest', 'freeway', 'golf_course', 'harbor', 'intersection', 'medium_residential', 'mobile_home_park', 'overpass', 'parking_lot', 'river', 'runway', 'sparse_residential', 'storage_tank', 'tennis_court']
# {'Train': '/panfs/roc/groups/14/kumarbio/rai00016/Capstone/Data/NWPURESISC_19/Train', 'Validation': '/panfs/roc/groups/14/kumarbio/rai00016/Capstone/Data/NWPURESISC_19/Validation', 'Test': '/panfs/roc/groups/14/kumarbio/rai00016/Capstone/Data/NWPURESISC_19/Test'}

# %%
def get_bottleneck_features(model, dataset, batch_size=64):
    print("Generating dataset")
    image_data_gen = ImageDataGenerator(rescale=1/255.0)
    image_generator = image_data_gen.flow_from_directory(target_dirs[dataset],
                                                        batch_size=batch_size,
                                                        shuffle=False)
    image_count = 0
    X_batches, Y_batches = [], []
    for X, Y in image_generator:
        X_batches.append(model.predict_on_batch(X))
        Y_batches.append(Y)
        image_count += X.shape[0]
    # Must interrupt image_generator
        if image_count >= image_generator.n:
            break
    X = np.concatenate(X_batches)
    Y = np.concatenate(Y_batches)
    return X, Y

# %%
pretrained_model = applications.InceptionResNetV2(include_top=False, weights='imagenet')

# %%
num_classes = len(class_names)
X, Y = dict(), dict()
for dataset in [ 'Validation', 'Test', 'Train']:
    # Extract bottleneck features from pretrained model, predicting from "dataset" directory
    X[dataset], Y[dataset] = get_bottleneck_features(pretrained_model, dataset)
# Out:
# Generating dataset
# Found 1330 images belonging to 19 classes.
# Generating dataset
# Found 1330 images belonging to 19 classes.
# Generating dataset
# Found 10640 images belonging to 19 classes.

# %%
def build_fully_connected(input_shape, num_classes):
    """
    Create a fully-connected model to train or test on UC Merced dataset.
    """
    model = Sequential()
    model.add(Flatten(input_shape=input_shape))
    model.add(Dense(256))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    return model

# %%
model = build_fully_connected(input_shape=X['Train'].shape[1:], num_classes=num_classes)
adam = optimizers.Adam(lr=0.0001)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
model_fit_history = model.fit(X['Train'], Y['Train'], batch_size=64, epochs=300,
                              verbose=2, validation_data=(X['Validation'], Y['Validation']))
# Out:
# Train on 10640 samples, validate on 1330 samples
# Epoch 1/300
#  - 11s - loss: 1.4711 - accuracy: 0.5744 - val_loss: 0.6936 - val_accuracy: 0.7955
# Epoch 2/300
#  - 11s - loss: 0.7743 - accuracy: 0.7602 - val_loss: 0.5453 - val_accuracy: 0.8353
# Epoch 3/300
#  - 10s - loss: 0.5556 - accuracy: 0.8273 - val_loss: 0.5244 - val_accuracy: 0.8436
# Epoch 4/300
#  - 11s - loss: 0.4424 - accuracy: 0.8584 - val_loss: 0.4539 - val_accuracy: 0.8714
# Epoch 5/300
#  - 10s - loss: 0.3447 - accuracy: 0.8875 - val_loss: 0.4287 - val_accuracy: 0.8669
# Epoch 6/300
#  - 10s - loss: 0.3042 - accuracy: 0.9009 - val_loss: 0.4362 - val_accuracy: 0.8669
# Epoch 7/300
#  - 10s - loss: 0.2406 - accuracy: 0.9219 - val_loss: 0.4230 - val_accuracy: 0.8707
# Epoch 8/300
#  - 10s - loss: 0.2055 - accuracy: 0.9355 - val_loss: 0.4317 - val_accuracy: 0.8677
# Epoch 9/300
#  - 11s - loss: 0.1770 - accuracy: 0.9437 - val_loss: 0.4251 - val_accuracy: 0.8774
# Epoch 10/300
#  - 11s - loss: 0.1497 - accuracy: 0.9515 - val_loss: 0.4232 - val_accuracy: 0.8722
# Epoch 11/300
#  - 10s - loss: 0.1427 - accuracy: 0.9555 - val_loss: 0.4259 - val_accuracy: 0.8835
# Epoch 12/300
#  - 11s - loss: 0.1285 - accuracy: 0.9587 - val_loss: 0.4418 - val_accuracy: 0.8707
# Epoch 13/300
#  - 11s - loss: 0.1183 - accuracy: 0.9630 - val_loss: 0.4001 - val_accuracy: 0.8789
# Epoch 14/300
#  - 10s - loss: 0.1013 - accuracy: 0.9680 - val_loss: 0.4021 - val_accuracy: 0.8782
# Epoch 15/300
#  - 11s - loss: 0.0968 - accuracy: 0.9692 - val_loss: 0.4186 - val_accuracy: 0.8835
# Epoch 16/300
#  - 10s - loss: 0.0942 - accuracy: 0.9709 - val_loss: 0.4400 - val_accuracy: 0.8895
# Epoch 17/300
#  - 11s - loss: 0.0823 - accuracy: 0.9730 - val_loss: 0.4351 - val_accuracy: 0.8812
# Epoch 18/300
#  - 11s - loss: 0.0886 - accuracy: 0.9711 - val_loss: 0.4494 - val_accuracy: 0.8782
# Epoch 19/300
#  - 10s - loss: 0.0855 - accuracy: 0.9721 - val_loss: 0.4101 - val_accuracy: 0.8850
# Epoch 20/300
#  - 10s - loss: 0.0877 - accuracy: 0.9699 - val_loss: 0.4164 - val_accuracy: 0.8962
# Epoch 21/300
#  - 10s - loss: 0.0673 - accuracy: 0.9788 - val_loss: 0.4723 - val_accuracy: 0.8789
# Epoch 22/300
#  - 10s - loss: 0.0714 - accuracy: 0.9778 - val_loss: 0.4230 - val_accuracy: 0.8812
# Epoch 23/300
#  - 11s - loss: 0.0654 - accuracy: 0.9789 - val_loss: 0.4452 - val_accuracy: 0.8902
# Epoch 24/300
#  - 10s - loss: 0.0729 - accuracy: 0.9765 - val_loss: 0.4305 - val_accuracy: 0.8917
# Epoch 25/300
#  - 11s - loss: 0.0788 - accuracy: 0.9727 - val_loss: 0.5074 - val_accuracy: 0.8827
# Epoch 26/300
#  - 10s - loss: 0.0628 - accuracy: 0.9807 - val_loss: 0.4650 - val_accuracy: 0.8880
# Epoch 27/300
#  - 11s - loss: 0.0550 - accuracy: 0.9807 - val_loss: 0.5052 - val_accuracy: 0.8887
# Epoch 28/300
#  - 10s - loss: 0.0657 - accuracy: 0.9783 - val_loss: 0.4858 - val_accuracy: 0.8857
# Epoch 29/300
#  - 10s - loss: 0.0502 - accuracy: 0.9839 - val_loss: 0.4784 - val_accuracy: 0.8850
# Epoch 30/300
#  - 10s - loss: 0.0594 - accuracy: 0.9803 - val_loss: 0.4959 - val_accuracy: 0.8767
# Epoch 31/300
#  - 10s - loss: 0.0527 - accuracy: 0.9820 - val_loss: 0.4818 - val_accuracy: 0.8910
# Epoch 32/300
#  - 11s - loss: 0.0609 - accuracy: 0.9792 - val_loss: 0.5010 - val_accuracy: 0.8865
# Epoch 33/300
#  - 10s - loss: 0.0648 - accuracy: 0.9789 - val_loss: 0.4488 - val_accuracy: 0.8932
# Epoch 34/300
#  - 10s - loss: 0.0568 - accuracy: 0.9815 - val_loss: 0.4881 - val_accuracy: 0.8947
# Epoch 35/300
#  - 10s - loss: 0.0539 - accuracy: 0.9820 - val_loss: 0.5122 - val_accuracy: 0.8827
# Epoch 36/300
#  - 10s - loss: 0.0501 - accuracy: 0.9840 - val_loss: 0.5502 - val_accuracy: 0.8774
# Epoch 37/300
#  - 10s - loss: 0.0530 - accuracy: 0.9818 - val_loss: 0.5098 - val_accuracy: 0.8880
# Epoch 38/300
#  - 10s - loss: 0.0502 - accuracy: 0.9835 - val_loss: 0.5090 - val_accuracy: 0.8835
# Epoch 39/300
#  - 10s - loss: 0.0520 - accuracy: 0.9823 - val_loss: 0.6235 - val_accuracy: 0.8714
# Epoch 40/300
#  - 11s - loss: 0.0497 - accuracy: 0.9837 - val_loss: 0.5374 - val_accuracy: 0.8812
# Epoch 41/300
#  - 10s - loss: 0.0493 - accuracy: 0.9836 - val_loss: 0.5477 - val_accuracy: 0.8850
# Epoch 42/300
#  - 10s - loss: 0.0541 - accuracy: 0.9819 - val_loss: 0.5079 - val_accuracy: 0.8789
# Epoch 43/300
#  - 10s - loss: 0.0439 - accuracy: 0.9852 - val_loss: 0.5219 - val_accuracy: 0.8902
# Epoch 44/300
#  - 10s - loss: 0.0499 - accuracy: 0.9817 - val_loss: 0.5491 - val_accuracy: 0.8827
# Epoch 45/300
#  - 11s - loss: 0.0520 - accuracy: 0.9828 - val_loss: 0.6156 - val_accuracy: 0.8714
# Epoch 46/300
#  - 10s - loss: 0.0445 - accuracy: 0.9841 - val_loss: 0.6164 - val_accuracy: 0.8692
# Epoch 47/300
#  - 10s - loss: 0.0419 - accuracy: 0.9856 - val_loss: 0.5795 - val_accuracy: 0.8737
# Epoch 48/300
#  - 11s - loss: 0.0381 - accuracy: 0.9883 - val_loss: 0.5933 - val_accuracy: 0.8797
# Epoch 49/300
#  - 10s - loss: 0.0426 - accuracy: 0.9851 - val_loss: 0.5182 - val_accuracy: 0.8820
# Epoch 50/300
#  - 10s - loss: 0.0363 - accuracy: 0.9867 - val_loss: 0.5509 - val_accuracy: 0.8940
# Epoch 51/300
#  - 11s - loss: 0.0370 - accuracy: 0.9866 - val_loss: 0.5319 - val_accuracy: 0.8805
# Epoch 52/300
#  - 10s - loss: 0.0463 - accuracy: 0.9841 - val_loss: 0.5987 - val_accuracy: 0.8850
# Epoch 53/300
#  - 10s - loss: 0.0472 - accuracy: 0.9826 - val_loss: 0.5573 - val_accuracy: 0.8880
# Epoch 54/300
#  - 10s - loss: 0.0496 - accuracy: 0.9826 - val_loss: 0.5514 - val_accuracy: 0.8902
# Epoch 55/300
#  - 11s - loss: 0.0447 - accuracy: 0.9852 - val_loss: 0.5756 - val_accuracy: 0.8842
# Epoch 56/300
#  - 10s - loss: 0.0482 - accuracy: 0.9847 - val_loss: 0.5763 - val_accuracy: 0.8887
# Epoch 57/300
#  - 10s - loss: 0.0368 - accuracy: 0.9876 - val_loss: 0.6199 - val_accuracy: 0.8820
# Epoch 58/300
#  - 11s - loss: 0.0407 - accuracy: 0.9879 - val_loss: 0.6397 - val_accuracy: 0.8850
# Epoch 59/300
#  - 11s - loss: 0.0453 - accuracy: 0.9856 - val_loss: 0.5813 - val_accuracy: 0.8820
# Epoch 60/300
#  - 10s - loss: 0.0429 - accuracy: 0.9864 - val_loss: 0.5994 - val_accuracy: 0.8812
# Epoch 61/300
#  - 11s - loss: 0.0356 - accuracy: 0.9879 - val_loss: 0.5638 - val_accuracy: 0.8872
# Epoch 62/300
#  - 11s - loss: 0.0282 - accuracy: 0.9901 - val_loss: 0.6454 - val_accuracy: 0.8857
# Epoch 63/300
#  - 11s - loss: 0.0371 - accuracy: 0.9879 - val_loss: 0.6329 - val_accuracy: 0.8805
# Epoch 64/300
#  - 11s - loss: 0.0367 - accuracy: 0.9867 - val_loss: 0.6525 - val_accuracy: 0.8767
# Epoch 65/300
#  - 11s - loss: 0.0387 - accuracy: 0.9860 - val_loss: 0.5973 - val_accuracy: 0.8842
# Epoch 66/300
#  - 10s - loss: 0.0325 - accuracy: 0.9895 - val_loss: 0.5790 - val_accuracy: 0.8872
# Epoch 67/300
#  - 10s - loss: 0.0310 - accuracy: 0.9890 - val_loss: 0.5700 - val_accuracy: 0.8857
# Epoch 68/300
#  - 10s - loss: 0.0389 - accuracy: 0.9880 - val_loss: 0.6509 - val_accuracy: 0.8744
# Epoch 69/300
#  - 11s - loss: 0.0346 - accuracy: 0.9885 - val_loss: 0.6064 - val_accuracy: 0.8782
# Epoch 70/300
#  - 11s - loss: 0.0371 - accuracy: 0.9872 - val_loss: 0.6555 - val_accuracy: 0.8842
# Epoch 71/300
#  - 11s - loss: 0.0230 - accuracy: 0.9919 - val_loss: 0.6684 - val_accuracy: 0.8835
# Epoch 72/300
#  - 11s - loss: 0.0379 - accuracy: 0.9867 - val_loss: 0.5783 - val_accuracy: 0.8842
# Epoch 73/300
#  - 11s - loss: 0.0349 - accuracy: 0.9874 - val_loss: 0.5603 - val_accuracy: 0.8925
# Epoch 74/300
#  - 10s - loss: 0.0296 - accuracy: 0.9903 - val_loss: 0.5971 - val_accuracy: 0.8910
# Epoch 75/300
#  - 11s - loss: 0.0334 - accuracy: 0.9881 - val_loss: 0.6638 - val_accuracy: 0.8812
# Epoch 76/300
#  - 10s - loss: 0.0274 - accuracy: 0.9917 - val_loss: 0.6300 - val_accuracy: 0.8827
# Epoch 77/300
#  - 10s - loss: 0.0379 - accuracy: 0.9868 - val_loss: 0.6632 - val_accuracy: 0.8842
# Epoch 78/300
#  - 11s - loss: 0.0290 - accuracy: 0.9901 - val_loss: 0.6855 - val_accuracy: 0.8744
# Epoch 79/300
#  - 10s - loss: 0.0318 - accuracy: 0.9883 - val_loss: 0.6210 - val_accuracy: 0.8887
# Epoch 80/300
#  - 11s - loss: 0.0324 - accuracy: 0.9887 - val_loss: 0.6332 - val_accuracy: 0.8767
# Epoch 81/300
#  - 11s - loss: 0.0356 - accuracy: 0.9876 - val_loss: 0.6569 - val_accuracy: 0.8752
# Epoch 82/300
#  - 11s - loss: 0.0288 - accuracy: 0.9904 - val_loss: 0.6127 - val_accuracy: 0.8895
# Epoch 83/300
#  - 11s - loss: 0.0281 - accuracy: 0.9902 - val_loss: 0.6269 - val_accuracy: 0.8865
# Epoch 84/300
#  - 10s - loss: 0.0272 - accuracy: 0.9911 - val_loss: 0.6774 - val_accuracy: 0.8865
# Epoch 85/300
#  - 10s - loss: 0.0363 - accuracy: 0.9880 - val_loss: 0.6654 - val_accuracy: 0.8902
# Epoch 86/300
#  - 10s - loss: 0.0388 - accuracy: 0.9874 - val_loss: 0.7356 - val_accuracy: 0.8759
# Epoch 87/300
#  - 10s - loss: 0.0302 - accuracy: 0.9899 - val_loss: 0.6933 - val_accuracy: 0.8857
# Epoch 88/300
#  - 11s - loss: 0.0265 - accuracy: 0.9917 - val_loss: 0.6967 - val_accuracy: 0.8827
# Epoch 89/300
#  - 11s - loss: 0.0347 - accuracy: 0.9883 - val_loss: 0.6546 - val_accuracy: 0.8887
# Epoch 90/300
#  - 11s - loss: 0.0265 - accuracy: 0.9917 - val_loss: 0.6759 - val_accuracy: 0.8887
# Epoch 91/300
#  - 10s - loss: 0.0357 - accuracy: 0.9880 - val_loss: 0.6925 - val_accuracy: 0.8820
# Epoch 92/300
#  - 10s - loss: 0.0325 - accuracy: 0.9898 - val_loss: 0.6846 - val_accuracy: 0.8865
# Epoch 93/300
#  - 11s - loss: 0.0309 - accuracy: 0.9885 - val_loss: 0.6876 - val_accuracy: 0.8865
# Epoch 94/300
#  - 11s - loss: 0.0234 - accuracy: 0.9914 - val_loss: 0.7272 - val_accuracy: 0.8805
# Epoch 95/300
#  - 10s - loss: 0.0270 - accuracy: 0.9911 - val_loss: 0.6928 - val_accuracy: 0.8737
# Epoch 96/300
#  - 11s - loss: 0.0301 - accuracy: 0.9897 - val_loss: 0.7306 - val_accuracy: 0.8835
# Epoch 97/300
#  - 10s - loss: 0.0302 - accuracy: 0.9898 - val_loss: 0.7111 - val_accuracy: 0.8857
# Epoch 98/300
#  - 10s - loss: 0.0257 - accuracy: 0.9910 - val_loss: 0.7166 - val_accuracy: 0.8842
# Epoch 99/300
#  - 11s - loss: 0.0226 - accuracy: 0.9924 - val_loss: 0.6708 - val_accuracy: 0.8947
# Epoch 100/300
#  - 11s - loss: 0.0269 - accuracy: 0.9914 - val_loss: 0.6995 - val_accuracy: 0.8805
# Epoch 101/300
#  - 10s - loss: 0.0233 - accuracy: 0.9927 - val_loss: 0.6809 - val_accuracy: 0.8850
# Epoch 102/300
#  - 10s - loss: 0.0221 - accuracy: 0.9916 - val_loss: 0.6754 - val_accuracy: 0.8842
# Epoch 103/300
#  - 10s - loss: 0.0248 - accuracy: 0.9912 - val_loss: 0.6553 - val_accuracy: 0.8857
# Epoch 104/300
#  - 11s - loss: 0.0229 - accuracy: 0.9922 - val_loss: 0.6775 - val_accuracy: 0.8902
# Epoch 105/300
#  - 11s - loss: 0.0291 - accuracy: 0.9903 - val_loss: 0.6937 - val_accuracy: 0.8827
# Epoch 106/300
#  - 10s - loss: 0.0289 - accuracy: 0.9893 - val_loss: 0.6434 - val_accuracy: 0.8955
# Epoch 107/300
#  - 11s - loss: 0.0328 - accuracy: 0.9886 - val_loss: 0.6748 - val_accuracy: 0.8895
# Epoch 108/300
#  - 11s - loss: 0.0244 - accuracy: 0.9914 - val_loss: 0.6631 - val_accuracy: 0.8880
# Epoch 109/300
#  - 11s - loss: 0.0278 - accuracy: 0.9900 - val_loss: 0.6992 - val_accuracy: 0.8947
# Epoch 110/300
#  - 11s - loss: 0.0365 - accuracy: 0.9879 - val_loss: 0.7007 - val_accuracy: 0.8827
# Epoch 111/300
#  - 11s - loss: 0.0223 - accuracy: 0.9927 - val_loss: 0.7109 - val_accuracy: 0.8880
# Epoch 112/300
#  - 11s - loss: 0.0191 - accuracy: 0.9937 - val_loss: 0.6954 - val_accuracy: 0.8820
# Epoch 113/300
#  - 11s - loss: 0.0209 - accuracy: 0.9920 - val_loss: 0.7291 - val_accuracy: 0.8805
# Epoch 114/300
#  - 11s - loss: 0.0312 - accuracy: 0.9893 - val_loss: 0.7765 - val_accuracy: 0.8812
# Epoch 115/300
#  - 11s - loss: 0.0290 - accuracy: 0.9902 - val_loss: 0.7697 - val_accuracy: 0.8805
# Epoch 116/300
#  - 11s - loss: 0.0256 - accuracy: 0.9914 - val_loss: 0.6711 - val_accuracy: 0.8895
# Epoch 117/300
#  - 11s - loss: 0.0232 - accuracy: 0.9921 - val_loss: 0.7519 - val_accuracy: 0.8812
# Epoch 118/300
#  - 11s - loss: 0.0213 - accuracy: 0.9916 - val_loss: 0.7717 - val_accuracy: 0.8880
# Epoch 119/300
#  - 11s - loss: 0.0222 - accuracy: 0.9914 - val_loss: 0.6687 - val_accuracy: 0.8872
# Epoch 120/300
#  - 11s - loss: 0.0217 - accuracy: 0.9932 - val_loss: 0.7438 - val_accuracy: 0.8850
# Epoch 121/300
#  - 11s - loss: 0.0288 - accuracy: 0.9902 - val_loss: 0.6677 - val_accuracy: 0.8850
# Epoch 122/300
#  - 11s - loss: 0.0358 - accuracy: 0.9877 - val_loss: 0.6841 - val_accuracy: 0.8842
# Epoch 123/300
#  - 11s - loss: 0.0242 - accuracy: 0.9921 - val_loss: 0.6855 - val_accuracy: 0.8880
# Epoch 124/300
#  - 10s - loss: 0.0267 - accuracy: 0.9912 - val_loss: 0.7344 - val_accuracy: 0.8865
# Epoch 125/300
#  - 11s - loss: 0.0160 - accuracy: 0.9943 - val_loss: 0.7710 - val_accuracy: 0.8857
# Epoch 126/300
#  - 11s - loss: 0.0211 - accuracy: 0.9930 - val_loss: 0.8032 - val_accuracy: 0.8789
# Epoch 127/300
#  - 11s - loss: 0.0224 - accuracy: 0.9924 - val_loss: 0.7005 - val_accuracy: 0.8842
# Epoch 128/300
#  - 11s - loss: 0.0193 - accuracy: 0.9941 - val_loss: 0.7678 - val_accuracy: 0.8865
# Epoch 129/300
#  - 11s - loss: 0.0219 - accuracy: 0.9925 - val_loss: 0.7490 - val_accuracy: 0.8827
# Epoch 130/300
#  - 10s - loss: 0.0194 - accuracy: 0.9934 - val_loss: 0.7869 - val_accuracy: 0.8887
# Epoch 131/300
#  - 10s - loss: 0.0268 - accuracy: 0.9901 - val_loss: 0.7467 - val_accuracy: 0.8850
# Epoch 132/300
#  - 10s - loss: 0.0182 - accuracy: 0.9935 - val_loss: 0.7936 - val_accuracy: 0.8827
# Epoch 133/300
#  - 11s - loss: 0.0272 - accuracy: 0.9900 - val_loss: 0.7675 - val_accuracy: 0.8767
# Epoch 134/300
#  - 10s - loss: 0.0197 - accuracy: 0.9939 - val_loss: 0.8085 - val_accuracy: 0.8820
# Epoch 135/300
#  - 11s - loss: 0.0148 - accuracy: 0.9951 - val_loss: 0.8757 - val_accuracy: 0.8850
# Epoch 136/300
#  - 10s - loss: 0.0179 - accuracy: 0.9937 - val_loss: 0.7611 - val_accuracy: 0.8917
# Epoch 137/300
#  - 10s - loss: 0.0269 - accuracy: 0.9908 - val_loss: 0.7824 - val_accuracy: 0.8857
# Epoch 138/300
#  - 10s - loss: 0.0181 - accuracy: 0.9935 - val_loss: 0.8055 - val_accuracy: 0.8895
# Epoch 139/300
#  - 10s - loss: 0.0227 - accuracy: 0.9920 - val_loss: 0.8029 - val_accuracy: 0.8947
# Epoch 140/300
#  - 10s - loss: 0.0239 - accuracy: 0.9930 - val_loss: 0.8343 - val_accuracy: 0.8857
# Epoch 141/300
#  - 10s - loss: 0.0253 - accuracy: 0.9913 - val_loss: 0.7716 - val_accuracy: 0.8759
# Epoch 142/300
#  - 11s - loss: 0.0216 - accuracy: 0.9931 - val_loss: 0.6759 - val_accuracy: 0.8970
# Epoch 143/300
#  - 10s - loss: 0.0164 - accuracy: 0.9942 - val_loss: 0.7589 - val_accuracy: 0.8827
# Epoch 144/300
#  - 11s - loss: 0.0205 - accuracy: 0.9925 - val_loss: 0.7176 - val_accuracy: 0.8820
# Epoch 145/300
#  - 10s - loss: 0.0180 - accuracy: 0.9944 - val_loss: 0.7502 - val_accuracy: 0.8842
# Epoch 146/300
#  - 10s - loss: 0.0256 - accuracy: 0.9916 - val_loss: 0.7728 - val_accuracy: 0.8850
# Epoch 147/300
#  - 10s - loss: 0.0176 - accuracy: 0.9938 - val_loss: 0.8108 - val_accuracy: 0.8812
# Epoch 148/300
#  - 10s - loss: 0.0147 - accuracy: 0.9947 - val_loss: 0.7291 - val_accuracy: 0.8962
# Epoch 149/300
#  - 10s - loss: 0.0222 - accuracy: 0.9921 - val_loss: 0.7356 - val_accuracy: 0.8925
# Epoch 150/300
#  - 10s - loss: 0.0180 - accuracy: 0.9937 - val_loss: 0.8095 - val_accuracy: 0.8835
# Epoch 151/300
#  - 10s - loss: 0.0241 - accuracy: 0.9933 - val_loss: 0.7911 - val_accuracy: 0.8782
# Epoch 152/300
#  - 11s - loss: 0.0166 - accuracy: 0.9936 - val_loss: 0.8041 - val_accuracy: 0.8865
# Epoch 153/300
#  - 11s - loss: 0.0199 - accuracy: 0.9936 - val_loss: 0.8083 - val_accuracy: 0.8820
# Epoch 154/300
#  - 11s - loss: 0.0217 - accuracy: 0.9920 - val_loss: 0.8227 - val_accuracy: 0.8820
# Epoch 155/300
#  - 11s - loss: 0.0245 - accuracy: 0.9917 - val_loss: 0.7649 - val_accuracy: 0.8789
# Epoch 156/300
#  - 11s - loss: 0.0209 - accuracy: 0.9935 - val_loss: 0.8121 - val_accuracy: 0.8789
# Epoch 157/300
#  - 11s - loss: 0.0252 - accuracy: 0.9919 - val_loss: 0.7426 - val_accuracy: 0.8805
# Epoch 158/300
#  - 11s - loss: 0.0154 - accuracy: 0.9936 - val_loss: 0.7781 - val_accuracy: 0.8835
# Epoch 159/300
#  - 11s - loss: 0.0151 - accuracy: 0.9954 - val_loss: 0.7624 - val_accuracy: 0.8782
# Epoch 160/300
#  - 10s - loss: 0.0177 - accuracy: 0.9946 - val_loss: 0.8834 - val_accuracy: 0.8789
# Epoch 161/300
#  - 10s - loss: 0.0283 - accuracy: 0.9912 - val_loss: 0.8360 - val_accuracy: 0.8820
# Epoch 162/300
#  - 11s - loss: 0.0257 - accuracy: 0.9915 - val_loss: 0.8571 - val_accuracy: 0.8812
# Epoch 163/300
#  - 11s - loss: 0.0281 - accuracy: 0.9901 - val_loss: 0.8326 - val_accuracy: 0.8842
# Epoch 164/300
#  - 10s - loss: 0.0212 - accuracy: 0.9927 - val_loss: 0.7400 - val_accuracy: 0.8910
# Epoch 165/300
#  - 11s - loss: 0.0194 - accuracy: 0.9931 - val_loss: 0.8296 - val_accuracy: 0.8872
# Epoch 166/300
#  - 11s - loss: 0.0142 - accuracy: 0.9955 - val_loss: 0.7889 - val_accuracy: 0.8895
# Epoch 167/300
#  - 10s - loss: 0.0180 - accuracy: 0.9938 - val_loss: 0.7795 - val_accuracy: 0.8865
# Epoch 168/300
#  - 10s - loss: 0.0171 - accuracy: 0.9945 - val_loss: 0.7804 - val_accuracy: 0.8850
# Epoch 169/300
#  - 10s - loss: 0.0189 - accuracy: 0.9936 - val_loss: 0.7942 - val_accuracy: 0.8842
# Epoch 170/300
#  - 11s - loss: 0.0191 - accuracy: 0.9932 - val_loss: 0.8110 - val_accuracy: 0.8857
# Epoch 171/300
#  - 11s - loss: 0.0171 - accuracy: 0.9941 - val_loss: 0.8661 - val_accuracy: 0.8842
# Epoch 172/300
#  - 10s - loss: 0.0188 - accuracy: 0.9929 - val_loss: 0.8447 - val_accuracy: 0.8895
# Epoch 173/300
#  - 10s - loss: 0.0168 - accuracy: 0.9941 - val_loss: 0.8385 - val_accuracy: 0.8850
# Epoch 174/300
#  - 11s - loss: 0.0191 - accuracy: 0.9944 - val_loss: 0.8545 - val_accuracy: 0.8729
# Epoch 175/300
#  - 11s - loss: 0.0174 - accuracy: 0.9934 - val_loss: 0.9706 - val_accuracy: 0.8744
# Epoch 176/300
#  - 10s - loss: 0.0214 - accuracy: 0.9929 - val_loss: 0.8859 - val_accuracy: 0.8865
# Epoch 177/300
#  - 10s - loss: 0.0221 - accuracy: 0.9915 - val_loss: 0.8161 - val_accuracy: 0.8865
# Epoch 178/300
#  - 11s - loss: 0.0230 - accuracy: 0.9920 - val_loss: 0.7750 - val_accuracy: 0.8917
# Epoch 179/300
#  - 10s - loss: 0.0158 - accuracy: 0.9943 - val_loss: 0.9502 - val_accuracy: 0.8865
# Epoch 180/300
#  - 11s - loss: 0.0160 - accuracy: 0.9945 - val_loss: 0.8663 - val_accuracy: 0.8880
# Epoch 181/300
#  - 10s - loss: 0.0241 - accuracy: 0.9914 - val_loss: 0.9341 - val_accuracy: 0.8797
# Epoch 182/300
#  - 10s - loss: 0.0120 - accuracy: 0.9961 - val_loss: 0.8449 - val_accuracy: 0.8835
# Epoch 183/300
#  - 10s - loss: 0.0096 - accuracy: 0.9970 - val_loss: 0.8803 - val_accuracy: 0.8835
# Epoch 184/300
#  - 11s - loss: 0.0194 - accuracy: 0.9939 - val_loss: 0.8483 - val_accuracy: 0.8797
# Epoch 185/300
#  - 10s - loss: 0.0333 - accuracy: 0.9895 - val_loss: 0.8280 - val_accuracy: 0.8857
# Epoch 186/300
#  - 10s - loss: 0.0158 - accuracy: 0.9942 - val_loss: 0.7966 - val_accuracy: 0.8880
# Epoch 187/300
#  - 10s - loss: 0.0167 - accuracy: 0.9940 - val_loss: 0.8801 - val_accuracy: 0.8812
# Epoch 188/300
#  - 10s - loss: 0.0196 - accuracy: 0.9940 - val_loss: 0.8455 - val_accuracy: 0.8782
# Epoch 189/300
#  - 11s - loss: 0.0185 - accuracy: 0.9945 - val_loss: 0.8170 - val_accuracy: 0.8850
# Epoch 190/300
#  - 11s - loss: 0.0203 - accuracy: 0.9942 - val_loss: 0.7639 - val_accuracy: 0.8857
# Epoch 191/300
#  - 11s - loss: 0.0118 - accuracy: 0.9958 - val_loss: 0.8565 - val_accuracy: 0.8850
# Epoch 192/300
#  - 11s - loss: 0.0173 - accuracy: 0.9950 - val_loss: 0.7716 - val_accuracy: 0.8842
# Epoch 193/300
#  - 11s - loss: 0.0164 - accuracy: 0.9950 - val_loss: 0.8484 - val_accuracy: 0.8887
# Epoch 194/300
#  - 10s - loss: 0.0130 - accuracy: 0.9959 - val_loss: 0.7354 - val_accuracy: 0.8835
# Epoch 195/300
#  - 11s - loss: 0.0137 - accuracy: 0.9956 - val_loss: 0.8298 - val_accuracy: 0.8857
# Epoch 196/300
#  - 11s - loss: 0.0182 - accuracy: 0.9938 - val_loss: 0.8586 - val_accuracy: 0.8805
# Epoch 197/300
#  - 11s - loss: 0.0174 - accuracy: 0.9940 - val_loss: 0.9146 - val_accuracy: 0.8835
# Epoch 198/300
#  - 11s - loss: 0.0163 - accuracy: 0.9937 - val_loss: 0.8535 - val_accuracy: 0.8902
# Epoch 199/300
#  - 10s - loss: 0.0223 - accuracy: 0.9925 - val_loss: 0.8463 - val_accuracy: 0.8805
# Epoch 200/300
#  - 10s - loss: 0.0201 - accuracy: 0.9943 - val_loss: 0.8538 - val_accuracy: 0.8850
# Epoch 201/300
#  - 10s - loss: 0.0116 - accuracy: 0.9961 - val_loss: 0.8960 - val_accuracy: 0.8752
# Epoch 202/300
#  - 11s - loss: 0.0100 - accuracy: 0.9966 - val_loss: 0.8637 - val_accuracy: 0.8865
# Epoch 203/300
#  - 10s - loss: 0.0165 - accuracy: 0.9937 - val_loss: 0.9641 - val_accuracy: 0.8902
# Epoch 204/300
#  - 11s - loss: 0.0229 - accuracy: 0.9930 - val_loss: 0.8809 - val_accuracy: 0.8835
# Epoch 205/300
#  - 10s - loss: 0.0155 - accuracy: 0.9948 - val_loss: 0.7882 - val_accuracy: 0.8932
# Epoch 206/300
#  - 10s - loss: 0.0165 - accuracy: 0.9945 - val_loss: 0.8868 - val_accuracy: 0.8842
# Epoch 207/300
#  - 11s - loss: 0.0154 - accuracy: 0.9949 - val_loss: 0.9410 - val_accuracy: 0.8857
# Epoch 208/300
#  - 10s - loss: 0.0219 - accuracy: 0.9925 - val_loss: 0.8087 - val_accuracy: 0.8902
# Epoch 209/300
#  - 10s - loss: 0.0148 - accuracy: 0.9948 - val_loss: 0.7568 - val_accuracy: 0.8887
# Epoch 210/300
#  - 11s - loss: 0.0148 - accuracy: 0.9954 - val_loss: 0.8456 - val_accuracy: 0.8827
# Epoch 211/300
#  - 11s - loss: 0.0137 - accuracy: 0.9957 - val_loss: 0.8789 - val_accuracy: 0.8782
# Epoch 212/300
#  - 10s - loss: 0.0092 - accuracy: 0.9965 - val_loss: 0.8816 - val_accuracy: 0.8880
# Epoch 213/300
#  - 11s - loss: 0.0150 - accuracy: 0.9949 - val_loss: 0.8212 - val_accuracy: 0.8842
# Epoch 214/300
#  - 11s - loss: 0.0180 - accuracy: 0.9946 - val_loss: 0.8204 - val_accuracy: 0.8857
# Epoch 215/300
#  - 11s - loss: 0.0170 - accuracy: 0.9956 - val_loss: 0.8270 - val_accuracy: 0.8992
# Epoch 216/300
#  - 11s - loss: 0.0115 - accuracy: 0.9965 - val_loss: 0.8330 - val_accuracy: 0.8880
# Epoch 217/300
#  - 11s - loss: 0.0247 - accuracy: 0.9928 - val_loss: 0.8380 - val_accuracy: 0.8895
# Epoch 218/300
#  - 11s - loss: 0.0163 - accuracy: 0.9952 - val_loss: 0.9396 - val_accuracy: 0.8835
# Epoch 219/300
#  - 11s - loss: 0.0246 - accuracy: 0.9915 - val_loss: 0.7661 - val_accuracy: 0.8850
# Epoch 220/300
#  - 11s - loss: 0.0124 - accuracy: 0.9957 - val_loss: 0.8320 - val_accuracy: 0.8887
# Epoch 221/300
#  - 11s - loss: 0.0155 - accuracy: 0.9950 - val_loss: 0.8892 - val_accuracy: 0.8850
# Epoch 222/300
#  - 11s - loss: 0.0158 - accuracy: 0.9945 - val_loss: 0.9040 - val_accuracy: 0.8797
# Epoch 223/300
#  - 11s - loss: 0.0100 - accuracy: 0.9961 - val_loss: 0.7883 - val_accuracy: 0.8925
# Epoch 224/300
#  - 11s - loss: 0.0120 - accuracy: 0.9961 - val_loss: 1.0125 - val_accuracy: 0.8812
# Epoch 225/300
#  - 11s - loss: 0.0180 - accuracy: 0.9942 - val_loss: 0.8716 - val_accuracy: 0.8805
# Epoch 226/300
#  - 11s - loss: 0.0161 - accuracy: 0.9945 - val_loss: 0.8533 - val_accuracy: 0.8857
# Epoch 227/300
#  - 11s - loss: 0.0174 - accuracy: 0.9938 - val_loss: 0.9806 - val_accuracy: 0.8805
# Epoch 228/300
#  - 11s - loss: 0.0255 - accuracy: 0.9929 - val_loss: 0.7493 - val_accuracy: 0.8827
# Epoch 229/300
#  - 11s - loss: 0.0132 - accuracy: 0.9953 - val_loss: 0.9142 - val_accuracy: 0.8812
# Epoch 230/300
#  - 11s - loss: 0.0112 - accuracy: 0.9966 - val_loss: 0.8653 - val_accuracy: 0.8857
# Epoch 231/300
#  - 11s - loss: 0.0156 - accuracy: 0.9941 - val_loss: 0.9959 - val_accuracy: 0.8842
# Epoch 232/300
#  - 11s - loss: 0.0176 - accuracy: 0.9951 - val_loss: 0.8310 - val_accuracy: 0.8820
# Epoch 233/300
#  - 11s - loss: 0.0122 - accuracy: 0.9958 - val_loss: 0.9241 - val_accuracy: 0.8797
# Epoch 234/300
#  - 11s - loss: 0.0145 - accuracy: 0.9953 - val_loss: 1.0089 - val_accuracy: 0.8917
# Epoch 235/300
#  - 11s - loss: 0.0174 - accuracy: 0.9943 - val_loss: 0.9310 - val_accuracy: 0.8910
# Epoch 236/300
#  - 11s - loss: 0.0151 - accuracy: 0.9951 - val_loss: 0.8648 - val_accuracy: 0.8850
# Epoch 237/300
#  - 12s - loss: 0.0163 - accuracy: 0.9943 - val_loss: 0.7937 - val_accuracy: 0.8872
# Epoch 238/300
#  - 11s - loss: 0.0179 - accuracy: 0.9943 - val_loss: 0.8319 - val_accuracy: 0.8850
# Epoch 239/300
#  - 11s - loss: 0.0215 - accuracy: 0.9930 - val_loss: 0.9098 - val_accuracy: 0.8812
# Epoch 240/300
#  - 11s - loss: 0.0202 - accuracy: 0.9929 - val_loss: 0.7640 - val_accuracy: 0.8977
# Epoch 241/300
#  - 11s - loss: 0.0139 - accuracy: 0.9956 - val_loss: 0.8232 - val_accuracy: 0.8917
# Epoch 242/300
#  - 12s - loss: 0.0137 - accuracy: 0.9953 - val_loss: 0.8965 - val_accuracy: 0.8955
# Epoch 243/300
#  - 12s - loss: 0.0291 - accuracy: 0.9914 - val_loss: 0.9031 - val_accuracy: 0.8812
# Epoch 244/300
#  - 12s - loss: 0.0157 - accuracy: 0.9954 - val_loss: 0.8498 - val_accuracy: 0.8902
# Epoch 245/300
#  - 12s - loss: 0.0112 - accuracy: 0.9955 - val_loss: 0.8865 - val_accuracy: 0.8962
# Epoch 246/300
#  - 11s - loss: 0.0161 - accuracy: 0.9945 - val_loss: 0.8603 - val_accuracy: 0.8940
# Epoch 247/300
#  - 11s - loss: 0.0171 - accuracy: 0.9947 - val_loss: 0.9594 - val_accuracy: 0.8865
# Epoch 248/300
#  - 11s - loss: 0.0191 - accuracy: 0.9942 - val_loss: 1.0048 - val_accuracy: 0.8827
# Epoch 249/300
#  - 11s - loss: 0.0120 - accuracy: 0.9962 - val_loss: 0.9906 - val_accuracy: 0.8857
# Epoch 250/300
#  - 11s - loss: 0.0132 - accuracy: 0.9960 - val_loss: 1.0532 - val_accuracy: 0.8872
# Epoch 251/300
#  - 11s - loss: 0.0191 - accuracy: 0.9941 - val_loss: 0.9570 - val_accuracy: 0.8992
# Epoch 252/300
#  - 11s - loss: 0.0183 - accuracy: 0.9943 - val_loss: 1.0176 - val_accuracy: 0.8805
# Epoch 253/300
#  - 11s - loss: 0.0166 - accuracy: 0.9945 - val_loss: 0.8760 - val_accuracy: 0.8872
# Epoch 254/300
#  - 10s - loss: 0.0167 - accuracy: 0.9942 - val_loss: 0.8768 - val_accuracy: 0.8857
# Epoch 255/300
#  - 11s - loss: 0.0102 - accuracy: 0.9964 - val_loss: 0.8710 - val_accuracy: 0.8865
# Epoch 256/300
#  - 11s - loss: 0.0135 - accuracy: 0.9962 - val_loss: 0.7933 - val_accuracy: 0.8902
# Epoch 257/300
#  - 11s - loss: 0.0099 - accuracy: 0.9955 - val_loss: 0.8306 - val_accuracy: 0.8880
# Epoch 258/300
#  - 11s - loss: 0.0121 - accuracy: 0.9956 - val_loss: 0.9007 - val_accuracy: 0.8895
# Epoch 259/300
#  - 11s - loss: 0.0164 - accuracy: 0.9945 - val_loss: 0.9261 - val_accuracy: 0.8865
# Epoch 260/300
#  - 11s - loss: 0.0160 - accuracy: 0.9946 - val_loss: 0.9747 - val_accuracy: 0.8865
# Epoch 261/300
#  - 10s - loss: 0.0244 - accuracy: 0.9932 - val_loss: 0.9454 - val_accuracy: 0.8880
# Epoch 262/300
#  - 11s - loss: 0.0180 - accuracy: 0.9946 - val_loss: 0.9238 - val_accuracy: 0.8827
# Epoch 263/300
#  - 11s - loss: 0.0096 - accuracy: 0.9969 - val_loss: 0.9035 - val_accuracy: 0.8820
# Epoch 264/300
#  - 10s - loss: 0.0094 - accuracy: 0.9970 - val_loss: 0.9479 - val_accuracy: 0.8850
# Epoch 265/300
#  - 10s - loss: 0.0259 - accuracy: 0.9927 - val_loss: 0.9026 - val_accuracy: 0.8895
# Epoch 266/300
#  - 11s - loss: 0.0162 - accuracy: 0.9950 - val_loss: 1.0742 - val_accuracy: 0.8782
# Epoch 267/300
#  - 10s - loss: 0.0193 - accuracy: 0.9941 - val_loss: 1.0331 - val_accuracy: 0.8782
# Epoch 268/300
#  - 10s - loss: 0.0149 - accuracy: 0.9945 - val_loss: 0.9390 - val_accuracy: 0.8872
# Epoch 269/300
#  - 10s - loss: 0.0110 - accuracy: 0.9967 - val_loss: 0.9110 - val_accuracy: 0.8850
# Epoch 270/300
#  - 10s - loss: 0.0081 - accuracy: 0.9977 - val_loss: 0.9192 - val_accuracy: 0.8880
# Epoch 271/300
#  - 10s - loss: 0.0107 - accuracy: 0.9964 - val_loss: 0.9160 - val_accuracy: 0.8910
# Epoch 272/300
#  - 11s - loss: 0.0099 - accuracy: 0.9968 - val_loss: 0.9656 - val_accuracy: 0.8880
# Epoch 273/300
#  - 10s - loss: 0.0191 - accuracy: 0.9943 - val_loss: 1.0034 - val_accuracy: 0.8759
# Epoch 274/300
#  - 10s - loss: 0.0199 - accuracy: 0.9944 - val_loss: 0.9053 - val_accuracy: 0.8880
# Epoch 275/300
#  - 10s - loss: 0.0147 - accuracy: 0.9946 - val_loss: 1.0564 - val_accuracy: 0.8789
# Epoch 276/300
#  - 10s - loss: 0.0138 - accuracy: 0.9958 - val_loss: 0.9615 - val_accuracy: 0.8797
# Epoch 277/300
#  - 11s - loss: 0.0110 - accuracy: 0.9964 - val_loss: 0.9353 - val_accuracy: 0.8857
# Epoch 278/300
#  - 10s - loss: 0.0117 - accuracy: 0.9959 - val_loss: 0.9464 - val_accuracy: 0.8925
# Epoch 279/300
#  - 10s - loss: 0.0174 - accuracy: 0.9944 - val_loss: 0.9987 - val_accuracy: 0.8872
# Epoch 280/300
#  - 10s - loss: 0.0194 - accuracy: 0.9945 - val_loss: 0.8710 - val_accuracy: 0.8812
# Epoch 281/300
#  - 10s - loss: 0.0151 - accuracy: 0.9946 - val_loss: 0.9983 - val_accuracy: 0.8902
# Epoch 282/300
#  - 11s - loss: 0.0161 - accuracy: 0.9950 - val_loss: 1.0751 - val_accuracy: 0.8865
# Epoch 283/300
#  - 11s - loss: 0.0092 - accuracy: 0.9967 - val_loss: 0.9937 - val_accuracy: 0.8835
# Epoch 284/300
#  - 10s - loss: 0.0125 - accuracy: 0.9955 - val_loss: 0.8918 - val_accuracy: 0.8910
# Epoch 285/300
#  - 10s - loss: 0.0133 - accuracy: 0.9959 - val_loss: 0.9786 - val_accuracy: 0.8782
# Epoch 286/300
#  - 10s - loss: 0.0139 - accuracy: 0.9952 - val_loss: 1.0376 - val_accuracy: 0.8842
# Epoch 287/300
#  - 10s - loss: 0.0184 - accuracy: 0.9939 - val_loss: 0.9806 - val_accuracy: 0.8940
# Epoch 288/300
#  - 10s - loss: 0.0155 - accuracy: 0.9956 - val_loss: 0.9787 - val_accuracy: 0.8887
# Epoch 289/300
#  - 11s - loss: 0.0161 - accuracy: 0.9946 - val_loss: 0.9380 - val_accuracy: 0.8917
# Epoch 290/300
#  - 11s - loss: 0.0208 - accuracy: 0.9933 - val_loss: 1.0734 - val_accuracy: 0.8767
# Epoch 291/300
#  - 10s - loss: 0.0161 - accuracy: 0.9950 - val_loss: 0.9611 - val_accuracy: 0.8925
# Epoch 292/300
#  - 10s - loss: 0.0133 - accuracy: 0.9947 - val_loss: 1.0254 - val_accuracy: 0.8857
# Epoch 293/300
#  - 10s - loss: 0.0114 - accuracy: 0.9968 - val_loss: 1.0895 - val_accuracy: 0.8932
# Epoch 294/300
#  - 10s - loss: 0.0226 - accuracy: 0.9934 - val_loss: 0.8605 - val_accuracy: 0.8940
# Epoch 295/300
#  - 10s - loss: 0.0099 - accuracy: 0.9970 - val_loss: 0.9601 - val_accuracy: 0.8895
# Epoch 296/300
#  - 10s - loss: 0.0099 - accuracy: 0.9966 - val_loss: 1.0180 - val_accuracy: 0.8827
# Epoch 297/300
#  - 10s - loss: 0.0097 - accuracy: 0.9971 - val_loss: 1.0483 - val_accuracy: 0.8880
# Epoch 298/300
#  - 10s - loss: 0.0173 - accuracy: 0.9948 - val_loss: 0.9440 - val_accuracy: 0.8925
# Epoch 299/300
#  - 11s - loss: 0.0123 - accuracy: 0.9955 - val_loss: 1.0117 - val_accuracy: 0.8887
# Epoch 300/300
#  - 11s - loss: 0.0140 - accuracy: 0.9960 - val_loss: 1.0740 - val_accuracy: 0.8797

# %%
epochs = len(model_fit_history.history['accuracy'])
plt.axis([0, epochs+1, 0, 1.2])
x = np.arange(1, epochs+1)
plt.plot(x, model_fit_history.history['accuracy'])
plt.plot(x, model_fit_history.history['val_accuracy'])
plt.title('Training accuracy vs. Validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='right')
plt.show()

# %%
epochs = len(model_fit_history.history['loss'])
max_loss = max(max(model_fit_history.history['loss']), max(model_fit_history.history['val_loss']))
plt.axis([0, epochs+1, 0, round(max_loss * 2.0) / 2 + 0.5])
x = np.arange(1, epochs+1)
plt.plot(x, model_fit_history.history['loss'])
plt.plot(x, model_fit_history.history['val_loss'])
plt.title('Training loss vs. Validation loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='right')
plt.show()

# %%
epochs = np.argmin(model_fit_history.history['val_loss']) + 1
print(epochs)
# Merge training and validation data
X_train = np.concatenate([X['Train'], X['Validation']])
Y_train = np.concatenate([Y['Train'], Y['Validation']])

# Randomly shuffle X and Y
shuffle_index = np.random.permutation(len(X_train))
X_train = X_train[shuffle_index]
Y_train = Y_train[shuffle_index]
model = build_fully_connected(input_shape=X_train.shape[1:], num_classes=num_classes)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
model_fit_history = model.fit(X_train, Y_train, batch_size=64, epochs=epochs, verbose=0)
# Out:
# 13

# %%
y_pred = model.predict_classes(X['Test'], verbose=0)

# %%
y_test = np.nonzero(Y['Test'])[1]
accuracy = accuracy_score(y_test, y_pred)

# %%
print(accuracy)
print(classification_report(y_test, y_pred))
# Out:
# 0.8789473684210526
#               precision    recall  f1-score   support
#
#            0       0.95      0.84      0.89        70
#            1       0.88      0.74      0.81        70
#            2       0.96      0.94      0.95        70
#            3       0.98      0.93      0.96        70
#            4       0.92      0.69      0.79        70
#            5       0.88      0.96      0.92        70
#            6       0.84      0.81      0.83        70
#            7       0.90      0.89      0.89        70
#            8       0.97      0.93      0.95        70
#            9       0.90      0.80      0.85        70
#           10       0.85      0.81      0.83        70
#           11       0.81      0.93      0.87        70
#           12       0.89      0.91      0.90        70
#           13       0.87      0.96      0.91        70
#           14       0.87      0.96      0.91        70
#           15       0.86      0.94      0.90        70
#           16       0.87      0.89      0.88        70
#           17       0.99      1.00      0.99        70
#           18       0.61      0.77      0.68        70
#
#     accuracy                           0.88      1330
#    macro avg       0.88      0.88      0.88      1330
# weighted avg       0.88      0.88      0.88      1330
