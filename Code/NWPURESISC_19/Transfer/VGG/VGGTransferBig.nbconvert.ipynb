# %%
from contextlib import suppress
import matplotlib
import matplotlib.pyplot as plt

import numpy as np
import os
import warnings

from keras import applications
from keras import optimizers
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, Flatten
from keras.utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import accuracy_score, classification_report
# Out:
# Using TensorFlow backend.

# %%
np.random.seed(8)

# %%
# !pwd
# Out:
# /home/kumarbio/rai00016/Capstone/Code

# %%
class_names = os.listdir('/panfs/roc/groups/14/kumarbio/rai00016/Capstone/Data/NWPURESISC_19/Train/')
target_dirs = {target: '/panfs/roc/groups/14/kumarbio/rai00016/Capstone/Data/NWPURESISC_19/' + target for target in ['Train', 'Validation', 'Test']}

# %%
print(class_names)
print(target_dirs)
# Out:
# ['airplane', 'baseball_diamond', 'beach', 'chaparral', 'dense_residential', 'forest', 'freeway', 'golf_course', 'harbor', 'intersection', 'medium_residential', 'mobile_home_park', 'overpass', 'parking_lot', 'river', 'runway', 'sparse_residential', 'storage_tank', 'tennis_court']
# {'Train': '/panfs/roc/groups/14/kumarbio/rai00016/Capstone/Data/NWPURESISC_19/Train', 'Validation': '/panfs/roc/groups/14/kumarbio/rai00016/Capstone/Data/NWPURESISC_19/Validation', 'Test': '/panfs/roc/groups/14/kumarbio/rai00016/Capstone/Data/NWPURESISC_19/Test'}

# %%
def get_bottleneck_features(model, dataset, batch_size=64):
    print("Generating dataset")
    image_data_gen = ImageDataGenerator(rescale=1/255.0)
    image_generator = image_data_gen.flow_from_directory(target_dirs[dataset],
                                                        batch_size=batch_size,
                                                        shuffle=False)
    image_count = 0
    X_batches, Y_batches = [], []
    for X, Y in image_generator:
        X_batches.append(model.predict_on_batch(X))
        Y_batches.append(Y)
        image_count += X.shape[0]
    # Must interrupt image_generator
        if image_count >= image_generator.n:
            break
    X = np.concatenate(X_batches)
    Y = np.concatenate(Y_batches)
    return X, Y

# %%
pretrained_model = applications.VGG16(include_top=False, weights='imagenet')

# %%
num_classes = len(class_names)
X, Y = dict(), dict()
for dataset in [ 'Validation', 'Test', 'Train']:
    # Extract bottleneck features from pretrained model, predicting from "dataset" directory
    X[dataset], Y[dataset] = get_bottleneck_features(pretrained_model, dataset)
# Out:
# Generating dataset
# Found 1330 images belonging to 19 classes.
# Generating dataset
# Found 1330 images belonging to 19 classes.
# Generating dataset
# Found 10640 images belonging to 19 classes.

# %%
def build_fully_connected(input_shape, num_classes):
    """
    Create a fully-connected model to train or test on UC Merced dataset.
    """
    model = Sequential()
    model.add(Flatten(input_shape=input_shape))
    model.add(Dense(256))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    return model

# %%
model = build_fully_connected(input_shape=X['Train'].shape[1:], num_classes=num_classes)
adam = optimizers.Adam(lr=0.0001)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
model_fit_history = model.fit(X['Train'], Y['Train'], batch_size=64, epochs=300,
                              verbose=2, validation_data=(X['Validation'], Y['Validation']))
# Out:
# Train on 10640 samples, validate on 1330 samples
# Epoch 1/300
#  - 7s - loss: 1.5650 - accuracy: 0.5262 - val_loss: 0.9253 - val_accuracy: 0.7376
# Epoch 2/300
#  - 7s - loss: 0.8878 - accuracy: 0.7297 - val_loss: 0.7173 - val_accuracy: 0.7962
# Epoch 3/300
#  - 8s - loss: 0.6731 - accuracy: 0.7951 - val_loss: 0.6560 - val_accuracy: 0.8083
# Epoch 4/300
# Epoch 78/300
#  - 7s - loss: 0.0182 - accuracy: 0.9951 - val_loss: 0.6522 - val_accuracy: 0.8429
# Epoch 79/300
#  - 7s - loss: 0.0150 - accuracy: 0.9958 - val_loss: 0.6343 - val_accuracy: 0.8474
# Epoch 80/300
#  - 7s - loss: 0.0141 - accuracy: 0.9965 - val_loss: 0.6870 - val_accuracy: 0.8293
# Epoch 81/300
#  - 7s - loss: 0.0112 - accuracy: 0.9976 - val_loss: 0.6460 - val_accuracy: 0.8466
# Epoch 82/300
#  - 8s - loss: 0.0083 - accuracy: 0.9985 - val_loss: 0.6353 - val_accuracy: 0.8481
# Epoch 83/300
#  - 8s - loss: 0.0136 - accuracy: 0.9961 - val_loss: 0.6388 - val_accuracy: 0.8444
# Epoch 84/300
#  - 7s - loss: 0.0118 - accuracy: 0.9974 - val_loss: 0.6497 - val_accuracy: 0.8466
# Epoch 85/300
#  - 6s - loss: 0.0094 - accuracy: 0.9979 - val_loss: 0.6766 - val_accuracy: 0.8414
# Epoch 86/300
#  - 6s - loss: 0.0105 - accuracy: 0.9976 - val_loss: 0.6585 - val_accuracy: 0.8466
# Epoch 87/300
#  - 7s - loss: 0.0106 - accuracy: 0.9978 - val_loss: 0.6218 - val_accuracy: 0.8579
# Epoch 88/300
#  - 6s - loss: 0.0086 - accuracy: 0.9983 - val_loss: 0.6825 - val_accuracy: 0.8436
# Epoch 89/300
#  - 7s - loss: 0.0105 - accuracy: 0.9974 - val_loss: 0.6311 - val_accuracy: 0.8541
# Epoch 90/300
#  - 7s - loss: 0.0114 - accuracy: 0.9971 - val_loss: 0.6496 - val_accuracy: 0.8466
# Epoch 91/300
#  - 7s - loss: 0.0078 - accuracy: 0.9980 - val_loss: 0.6600 - val_accuracy: 0.8414
# Epoch 92/300
#  - 7s - loss: 0.0069 - accuracy: 0.9988 - val_loss: 0.6557 - val_accuracy: 0.8526
# Epoch 93/300
#  - 7s - loss: 0.0114 - accuracy: 0.9963 - val_loss: 0.6630 - val_accuracy: 0.8421
# Epoch 94/300
#  - 7s - loss: 0.0085 - accuracy: 0.9980 - val_loss: 0.6752 - val_accuracy: 0.8511
# Epoch 95/300
#  - 7s - loss: 0.0190 - accuracy: 0.9938 - val_loss: 0.6554 - val_accuracy: 0.8481
# Epoch 96/300
#  - 7s - loss: 0.0112 - accuracy: 0.9968 - val_loss: 0.7342 - val_accuracy: 0.8444
# Epoch 97/300
#  - 7s - loss: 0.0098 - accuracy: 0.9976 - val_loss: 0.6690 - val_accuracy: 0.8571
# Epoch 98/300
#  - 9s - loss: 0.0086 - accuracy: 0.9981 - val_loss: 0.6984 - val_accuracy: 0.8421
# Epoch 99/300
#  - 6s - loss: 0.0119 - accuracy: 0.9971 - val_loss: 0.6430 - val_accuracy: 0.8504
# Epoch 100/300
#  - 6s - loss: 0.0075 - accuracy: 0.9982 - val_loss: 0.7079 - val_accuracy: 0.8421
# Epoch 101/300
#  - 7s - loss: 0.0086 - accuracy: 0.9977 - val_loss: 0.6771 - val_accuracy: 0.8466
# Epoch 102/300
#  - 7s - loss: 0.0074 - accuracy: 0.9980 - val_loss: 0.7035 - val_accuracy: 0.8451
# Epoch 103/300
#  - 7s - loss: 0.0065 - accuracy: 0.9982 - val_loss: 0.6648 - val_accuracy: 0.8556
# Epoch 104/300
#  - 7s - loss: 0.0102 - accuracy: 0.9974 - val_loss: 0.6881 - val_accuracy: 0.8534
# Epoch 105/300
#  - 7s - loss: 0.0079 - accuracy: 0.9978 - val_loss: 0.7065 - val_accuracy: 0.8436
# Epoch 106/300
#  - 7s - loss: 0.0119 - accuracy: 0.9969 - val_loss: 0.6940 - val_accuracy: 0.8526
# Epoch 107/300
#  - 7s - loss: 0.0068 - accuracy: 0.9985 - val_loss: 0.6992 - val_accuracy: 0.8511
# Epoch 108/300
#  - 7s - loss: 0.0087 - accuracy: 0.9972 - val_loss: 0.7062 - val_accuracy: 0.8481
# Epoch 109/300
#  - 7s - loss: 0.0111 - accuracy: 0.9969 - val_loss: 0.6845 - val_accuracy: 0.8549
# Epoch 110/300
#  - 7s - loss: 0.0066 - accuracy: 0.9982 - val_loss: 0.8069 - val_accuracy: 0.8301
# Epoch 111/300
#  - 7s - loss: 0.0098 - accuracy: 0.9976 - val_loss: 0.7709 - val_accuracy: 0.8338
# Epoch 112/300
#  - 7s - loss: 0.0075 - accuracy: 0.9981 - val_loss: 0.7166 - val_accuracy: 0.8489
# Epoch 113/300
#  - 7s - loss: 0.0116 - accuracy: 0.9967 - val_loss: 0.6989 - val_accuracy: 0.8466
# Epoch 114/300
#  - 7s - loss: 0.0097 - accuracy: 0.9980 - val_loss: 0.7279 - val_accuracy: 0.8444
# Epoch 115/300
#  - 7s - loss: 0.0163 - accuracy: 0.9941 - val_loss: 0.7467 - val_accuracy: 0.8474
# Epoch 116/300
#  - 7s - loss: 0.0063 - accuracy: 0.9986 - val_loss: 0.7442 - val_accuracy: 0.8519
# Epoch 117/300
#  - 7s - loss: 0.0054 - accuracy: 0.9988 - val_loss: 0.7118 - val_accuracy: 0.8504
# Epoch 118/300
#  - 7s - loss: 0.0074 - accuracy: 0.9980 - val_loss: 0.6917 - val_accuracy: 0.8541
# Epoch 119/300
#  - 6s - loss: 0.0080 - accuracy: 0.9978 - val_loss: 0.7211 - val_accuracy: 0.8444
# Epoch 120/300
#  - 6s - loss: 0.0030 - accuracy: 0.9997 - val_loss: 0.6988 - val_accuracy: 0.8556
# Epoch 121/300
#  - 7s - loss: 0.0067 - accuracy: 0.9983 - val_loss: 0.7431 - val_accuracy: 0.8474
# Epoch 122/300
#  - 7s - loss: 0.0078 - accuracy: 0.9979 - val_loss: 0.7420 - val_accuracy: 0.8466
# Epoch 123/300
#  - 6s - loss: 0.0107 - accuracy: 0.9969 - val_loss: 0.7310 - val_accuracy: 0.8451
# Epoch 124/300
#  - 7s - loss: 0.0092 - accuracy: 0.9974 - val_loss: 0.7143 - val_accuracy: 0.8541
# Epoch 125/300
#  - 7s - loss: 0.0077 - accuracy: 0.9978 - val_loss: 0.7634 - val_accuracy: 0.8519
# Epoch 126/300
#  - 7s - loss: 0.0035 - accuracy: 0.9993 - val_loss: 0.7636 - val_accuracy: 0.8519
# Epoch 127/300
#  - 6s - loss: 0.0081 - accuracy: 0.9978 - val_loss: 0.7098 - val_accuracy: 0.8594
# Epoch 128/300
#  - 7s - loss: 0.0078 - accuracy: 0.9977 - val_loss: 0.7984 - val_accuracy: 0.8466
# Epoch 129/300
#  - 7s - loss: 0.0066 - accuracy: 0.9982 - val_loss: 0.8253 - val_accuracy: 0.8474
# Epoch 130/300
#  - 7s - loss: 0.0074 - accuracy: 0.9981 - val_loss: 0.7541 - val_accuracy: 0.8496
# Epoch 131/300
#  - 6s - loss: 0.0095 - accuracy: 0.9971 - val_loss: 0.7319 - val_accuracy: 0.8526
# Epoch 132/300
#  - 7s - loss: 0.0083 - accuracy: 0.9977 - val_loss: 0.9466 - val_accuracy: 0.8301
# Epoch 133/300
#  - 7s - loss: 0.0120 - accuracy: 0.9965 - val_loss: 0.7926 - val_accuracy: 0.8368
# Epoch 134/300
#  - 7s - loss: 0.0064 - accuracy: 0.9986 - val_loss: 0.7855 - val_accuracy: 0.8436
# Epoch 135/300
#  - 7s - loss: 0.0044 - accuracy: 0.9989 - val_loss: 0.7772 - val_accuracy: 0.8511
# Epoch 136/300
#  - 7s - loss: 0.0037 - accuracy: 0.9994 - val_loss: 0.7889 - val_accuracy: 0.8444
# Epoch 137/300
#  - 7s - loss: 0.0060 - accuracy: 0.9982 - val_loss: 0.7309 - val_accuracy: 0.8459
# Epoch 138/300
#  - 6s - loss: 0.0088 - accuracy: 0.9975 - val_loss: 0.7346 - val_accuracy: 0.8459
# Epoch 139/300
#  - 7s - loss: 0.0049 - accuracy: 0.9988 - val_loss: 0.7894 - val_accuracy: 0.8534
# Epoch 140/300
#  - 7s - loss: 0.0071 - accuracy: 0.9978 - val_loss: 0.8710 - val_accuracy: 0.8293
# Epoch 141/300
#  - 7s - loss: 0.0081 - accuracy: 0.9977 - val_loss: 0.7633 - val_accuracy: 0.8519
# Epoch 142/300
#  - 7s - loss: 0.0053 - accuracy: 0.9992 - val_loss: 0.7886 - val_accuracy: 0.8474
# Epoch 143/300
#  - 6s - loss: 0.0062 - accuracy: 0.9982 - val_loss: 0.7598 - val_accuracy: 0.8579
# Epoch 144/300
#  - 7s - loss: 0.0139 - accuracy: 0.9956 - val_loss: 0.8714 - val_accuracy: 0.8383
# Epoch 145/300
#  - 6s - loss: 0.0106 - accuracy: 0.9961 - val_loss: 0.7840 - val_accuracy: 0.8496
# Epoch 146/300
#  - 7s - loss: 0.0052 - accuracy: 0.9985 - val_loss: 0.7983 - val_accuracy: 0.8549
# Epoch 147/300
#  - 7s - loss: 0.0065 - accuracy: 0.9982 - val_loss: 0.7679 - val_accuracy: 0.8459
# Epoch 148/300
#  - 7s - loss: 0.0068 - accuracy: 0.9982 - val_loss: 0.7332 - val_accuracy: 0.8556
# Epoch 149/300
#  - 7s - loss: 0.0097 - accuracy: 0.9970 - val_loss: 0.8006 - val_accuracy: 0.8556
# Epoch 150/300
#  - 7s - loss: 0.0058 - accuracy: 0.9988 - val_loss: 0.7617 - val_accuracy: 0.8556
# Epoch 151/300
#  - 7s - loss: 0.0065 - accuracy: 0.9977 - val_loss: 0.7531 - val_accuracy: 0.8579
# Epoch 152/300
#  - 7s - loss: 0.0063 - accuracy: 0.9983 - val_loss: 0.6892 - val_accuracy: 0.8617
# Epoch 153/300
#  - 6s - loss: 0.0077 - accuracy: 0.9977 - val_loss: 0.7887 - val_accuracy: 0.8421
# Epoch 154/300
#  - 7s - loss: 0.0086 - accuracy: 0.9973 - val_loss: 0.7550 - val_accuracy: 0.8541
# Epoch 155/300
#  - 7s - loss: 0.0044 - accuracy: 0.9991 - val_loss: 0.8719 - val_accuracy: 0.8436
# Epoch 156/300
#  - 7s - loss: 0.0059 - accuracy: 0.9980 - val_loss: 0.7970 - val_accuracy: 0.8474
# Epoch 157/300
#  - 7s - loss: 0.0057 - accuracy: 0.9988 - val_loss: 0.8665 - val_accuracy: 0.8429
# Epoch 158/300
#  - 7s - loss: 0.0046 - accuracy: 0.9989 - val_loss: 0.9546 - val_accuracy: 0.8323
# Epoch 159/300
#  - 7s - loss: 0.0088 - accuracy: 0.9969 - val_loss: 0.7759 - val_accuracy: 0.8511
# Epoch 160/300
#  - 7s - loss: 0.0088 - accuracy: 0.9975 - val_loss: 0.7336 - val_accuracy: 0.8556
# Epoch 161/300
#  - 6s - loss: 0.0074 - accuracy: 0.9979 - val_loss: 0.8165 - val_accuracy: 0.8481
# Epoch 162/300
#  - 6s - loss: 0.0051 - accuracy: 0.9988 - val_loss: 0.7835 - val_accuracy: 0.8511
# Epoch 163/300
#  - 7s - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.8342 - val_accuracy: 0.8346
# Epoch 164/300
#  - 7s - loss: 0.0053 - accuracy: 0.9985 - val_loss: 0.8719 - val_accuracy: 0.8376
# Epoch 165/300
#  - 7s - loss: 0.0068 - accuracy: 0.9979 - val_loss: 0.7714 - val_accuracy: 0.8526
# Epoch 166/300
#  - 7s - loss: 0.0171 - accuracy: 0.9941 - val_loss: 0.7597 - val_accuracy: 0.8481
# Epoch 167/300
#  - 6s - loss: 0.0097 - accuracy: 0.9975 - val_loss: 0.7740 - val_accuracy: 0.8519
# Epoch 168/300
#  - 7s - loss: 0.0050 - accuracy: 0.9983 - val_loss: 0.7748 - val_accuracy: 0.8511
# Epoch 169/300
#  - 6s - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.7939 - val_accuracy: 0.8451
# Epoch 170/300
#  - 6s - loss: 0.0057 - accuracy: 0.9984 - val_loss: 0.7824 - val_accuracy: 0.8526
# Epoch 171/300
#  - 7s - loss: 0.0104 - accuracy: 0.9966 - val_loss: 0.7645 - val_accuracy: 0.8526
# Epoch 172/300
#  - 7s - loss: 0.0057 - accuracy: 0.9984 - val_loss: 0.7320 - val_accuracy: 0.8526
# Epoch 173/300
#  - 6s - loss: 0.0039 - accuracy: 0.9991 - val_loss: 0.7990 - val_accuracy: 0.8429
# Epoch 174/300
#  - 7s - loss: 0.0040 - accuracy: 0.9988 - val_loss: 0.8221 - val_accuracy: 0.8376
# Epoch 175/300
#  - 7s - loss: 0.0071 - accuracy: 0.9981 - val_loss: 0.8557 - val_accuracy: 0.8459
# Epoch 176/300
#  - 8s - loss: 0.0090 - accuracy: 0.9966 - val_loss: 0.7536 - val_accuracy: 0.8519
# Epoch 177/300
#  - 7s - loss: 0.0070 - accuracy: 0.9977 - val_loss: 0.7940 - val_accuracy: 0.8466
# Epoch 178/300
#  - 7s - loss: 0.0053 - accuracy: 0.9983 - val_loss: 0.7663 - val_accuracy: 0.8436
# Epoch 179/300
#  - 7s - loss: 0.0062 - accuracy: 0.9979 - val_loss: 0.7875 - val_accuracy: 0.8451
# Epoch 180/300
#  - 7s - loss: 0.0067 - accuracy: 0.9983 - val_loss: 0.8204 - val_accuracy: 0.8526
# Epoch 181/300
#  - 8s - loss: 0.0048 - accuracy: 0.9989 - val_loss: 0.8127 - val_accuracy: 0.8459
# Epoch 182/300
#  - 7s - loss: 0.0045 - accuracy: 0.9988 - val_loss: 0.8188 - val_accuracy: 0.8504
# Epoch 183/300
#  - 6s - loss: 0.0043 - accuracy: 0.9988 - val_loss: 0.8410 - val_accuracy: 0.8511
# Epoch 184/300
#  - 6s - loss: 0.0042 - accuracy: 0.9986 - val_loss: 0.8727 - val_accuracy: 0.8361
# Epoch 185/300
#  - 7s - loss: 0.0085 - accuracy: 0.9968 - val_loss: 0.8307 - val_accuracy: 0.8338
# Epoch 186/300
#  - 7s - loss: 0.0108 - accuracy: 0.9967 - val_loss: 0.7851 - val_accuracy: 0.8406
# Epoch 187/300
#  - 6s - loss: 0.0115 - accuracy: 0.9968 - val_loss: 0.7465 - val_accuracy: 0.8541
# Epoch 188/300
#  - 7s - loss: 0.0052 - accuracy: 0.9985 - val_loss: 0.7973 - val_accuracy: 0.8549
# Epoch 189/300
#  - 8s - loss: 0.0075 - accuracy: 0.9975 - val_loss: 0.8002 - val_accuracy: 0.8444
# Epoch 190/300
#  - 8s - loss: 0.0068 - accuracy: 0.9977 - val_loss: 0.8382 - val_accuracy: 0.8406
# Epoch 191/300
#  - 7s - loss: 0.0046 - accuracy: 0.9986 - val_loss: 0.8009 - val_accuracy: 0.8429
# Epoch 192/300
#  - 7s - loss: 0.0050 - accuracy: 0.9987 - val_loss: 0.8232 - val_accuracy: 0.8474
# Epoch 193/300
#  - 7s - loss: 0.0062 - accuracy: 0.9978 - val_loss: 0.8233 - val_accuracy: 0.8511
# Epoch 194/300
#  - 7s - loss: 0.0064 - accuracy: 0.9979 - val_loss: 0.8624 - val_accuracy: 0.8504
# Epoch 195/300
#  - 7s - loss: 0.0027 - accuracy: 0.9994 - val_loss: 0.8993 - val_accuracy: 0.8466
# Epoch 196/300
#  - 6s - loss: 0.0041 - accuracy: 0.9988 - val_loss: 0.9508 - val_accuracy: 0.8383
# Epoch 197/300
#  - 7s - loss: 0.0083 - accuracy: 0.9974 - val_loss: 0.8389 - val_accuracy: 0.8534
# Epoch 198/300
#  - 7s - loss: 0.0089 - accuracy: 0.9979 - val_loss: 0.9408 - val_accuracy: 0.8361
# Epoch 199/300
#  - 8s - loss: 0.0083 - accuracy: 0.9981 - val_loss: 0.8625 - val_accuracy: 0.8444
# Epoch 200/300
#  - 8s - loss: 0.0078 - accuracy: 0.9978 - val_loss: 0.8801 - val_accuracy: 0.8519
# Epoch 201/300
#  - 8s - loss: 0.0079 - accuracy: 0.9972 - val_loss: 0.7794 - val_accuracy: 0.8549
# Epoch 202/300
#  - 7s - loss: 0.0070 - accuracy: 0.9984 - val_loss: 0.7840 - val_accuracy: 0.8504
# Epoch 203/300
#  - 7s - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.8372 - val_accuracy: 0.8496
# Epoch 204/300
#  - 7s - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.8848 - val_accuracy: 0.8541
# Epoch 205/300
#  - 7s - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.8625 - val_accuracy: 0.8496
# Epoch 206/300
#  - 7s - loss: 0.0062 - accuracy: 0.9982 - val_loss: 0.9306 - val_accuracy: 0.8398
# Epoch 207/300
#  - 7s - loss: 0.0040 - accuracy: 0.9991 - val_loss: 0.8260 - val_accuracy: 0.8519
# Epoch 208/300
#  - 7s - loss: 0.0128 - accuracy: 0.9949 - val_loss: 0.8366 - val_accuracy: 0.8511
# Epoch 209/300
#  - 7s - loss: 0.0070 - accuracy: 0.9983 - val_loss: 0.8015 - val_accuracy: 0.8519
# Epoch 210/300
#  - 7s - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.7987 - val_accuracy: 0.8496
# Epoch 211/300
#  - 6s - loss: 0.0047 - accuracy: 0.9984 - val_loss: 0.8616 - val_accuracy: 0.8541
# Epoch 212/300
#  - 7s - loss: 0.0086 - accuracy: 0.9969 - val_loss: 0.7977 - val_accuracy: 0.8496
# Epoch 213/300
#  - 7s - loss: 0.0058 - accuracy: 0.9985 - val_loss: 0.9668 - val_accuracy: 0.8406
# Epoch 214/300
#  - 7s - loss: 0.0084 - accuracy: 0.9969 - val_loss: 0.8246 - val_accuracy: 0.8534
# Epoch 215/300
#  - 9s - loss: 0.0064 - accuracy: 0.9981 - val_loss: 0.8045 - val_accuracy: 0.8481
# Epoch 216/300
#  - 7s - loss: 0.0043 - accuracy: 0.9987 - val_loss: 0.8256 - val_accuracy: 0.8556
# Epoch 217/300
#  - 7s - loss: 0.0051 - accuracy: 0.9985 - val_loss: 0.8706 - val_accuracy: 0.8504
# Epoch 218/300
#  - 7s - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.8814 - val_accuracy: 0.8519
# Epoch 219/300
#  - 7s - loss: 0.0066 - accuracy: 0.9978 - val_loss: 0.8797 - val_accuracy: 0.8466
# Epoch 220/300
#  - 6s - loss: 0.0133 - accuracy: 0.9956 - val_loss: 0.7842 - val_accuracy: 0.8511
# Epoch 221/300
#  - 7s - loss: 0.0035 - accuracy: 0.9991 - val_loss: 0.8240 - val_accuracy: 0.8564
# Epoch 222/300
#  - 7s - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.9391 - val_accuracy: 0.8489
# Epoch 223/300
#  - 7s - loss: 0.0041 - accuracy: 0.9986 - val_loss: 0.8958 - val_accuracy: 0.8541
# Epoch 224/300
#  - 7s - loss: 0.0095 - accuracy: 0.9965 - val_loss: 0.8052 - val_accuracy: 0.8519
# Epoch 225/300
#  - 7s - loss: 0.0051 - accuracy: 0.9989 - val_loss: 0.8764 - val_accuracy: 0.8466
# Epoch 226/300
#  - 8s - loss: 0.0086 - accuracy: 0.9973 - val_loss: 0.8620 - val_accuracy: 0.8459
# Epoch 227/300
#  - 7s - loss: 0.0059 - accuracy: 0.9977 - val_loss: 0.8569 - val_accuracy: 0.8398
# Epoch 228/300
#  - 7s - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.8679 - val_accuracy: 0.8504
# Epoch 229/300
#  - 6s - loss: 0.0067 - accuracy: 0.9977 - val_loss: 0.8582 - val_accuracy: 0.8474
# Epoch 230/300
#  - 7s - loss: 0.0023 - accuracy: 0.9992 - val_loss: 0.8833 - val_accuracy: 0.8541
# Epoch 231/300
#  - 7s - loss: 0.0023 - accuracy: 0.9992 - val_loss: 0.9196 - val_accuracy: 0.8526
# Epoch 232/300
#  - 7s - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.9658 - val_accuracy: 0.8338
# Epoch 233/300
#  - 7s - loss: 0.0095 - accuracy: 0.9963 - val_loss: 0.8901 - val_accuracy: 0.8451
# Epoch 234/300
#  - 7s - loss: 0.0047 - accuracy: 0.9984 - val_loss: 0.8703 - val_accuracy: 0.8519
# Epoch 235/300
#  - 7s - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.8732 - val_accuracy: 0.8564
# Epoch 236/300
#  - 7s - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.8854 - val_accuracy: 0.8511
# Epoch 237/300
#  - 6s - loss: 0.0056 - accuracy: 0.9980 - val_loss: 0.8294 - val_accuracy: 0.8466
# Epoch 238/300
#  - 7s - loss: 0.0137 - accuracy: 0.9958 - val_loss: 0.8023 - val_accuracy: 0.8436
# Epoch 239/300
#  - 7s - loss: 0.0096 - accuracy: 0.9968 - val_loss: 0.8613 - val_accuracy: 0.8609
# Epoch 240/300
#  - 7s - loss: 0.0041 - accuracy: 0.9989 - val_loss: 0.8626 - val_accuracy: 0.8489
# Epoch 241/300
#  - 6s - loss: 0.0058 - accuracy: 0.9980 - val_loss: 0.9209 - val_accuracy: 0.8489
# Epoch 242/300
#  - 7s - loss: 0.0047 - accuracy: 0.9987 - val_loss: 0.9631 - val_accuracy: 0.8436
# Epoch 243/300
#  - 7s - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.8858 - val_accuracy: 0.8556
# Epoch 244/300
#  - 7s - loss: 0.0057 - accuracy: 0.9980 - val_loss: 1.0076 - val_accuracy: 0.8421
# Epoch 245/300
#  - 7s - loss: 0.0049 - accuracy: 0.9981 - val_loss: 0.8592 - val_accuracy: 0.8541
# Epoch 246/300
#  - 6s - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.8699 - val_accuracy: 0.8481
# Epoch 247/300
#  - 7s - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.8891 - val_accuracy: 0.8549
# Epoch 248/300
#  - 10s - loss: 0.0037 - accuracy: 0.9989 - val_loss: 0.9461 - val_accuracy: 0.8549
# Epoch 249/300
#  - 8s - loss: 0.0096 - accuracy: 0.9962 - val_loss: 0.9469 - val_accuracy: 0.8406
# Epoch 250/300
#  - 7s - loss: 0.0089 - accuracy: 0.9969 - val_loss: 0.8715 - val_accuracy: 0.8504
# Epoch 251/300
#  - 7s - loss: 0.0026 - accuracy: 0.9995 - val_loss: 0.9036 - val_accuracy: 0.8466
# Epoch 252/300
#  - 7s - loss: 0.0033 - accuracy: 0.9988 - val_loss: 0.9300 - val_accuracy: 0.8346
# Epoch 253/300
#  - 7s - loss: 0.0072 - accuracy: 0.9977 - val_loss: 0.9504 - val_accuracy: 0.8459
# Epoch 254/300
#  - 7s - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.9124 - val_accuracy: 0.8526
# Epoch 255/300
#  - 7s - loss: 0.0060 - accuracy: 0.9976 - val_loss: 0.8308 - val_accuracy: 0.8489
# Epoch 256/300
#  - 7s - loss: 0.0045 - accuracy: 0.9982 - val_loss: 0.9129 - val_accuracy: 0.8489
# Epoch 257/300
#  - 7s - loss: 0.0070 - accuracy: 0.9976 - val_loss: 0.8974 - val_accuracy: 0.8481
# Epoch 258/300
#  - 7s - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.9113 - val_accuracy: 0.8481
# Epoch 259/300
#  - 7s - loss: 0.0079 - accuracy: 0.9975 - val_loss: 1.0010 - val_accuracy: 0.8414
# Epoch 260/300
#  - 7s - loss: 0.0069 - accuracy: 0.9977 - val_loss: 0.8117 - val_accuracy: 0.8541
# Epoch 261/300
#  - 7s - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.9343 - val_accuracy: 0.8466
# Epoch 262/300
#  - 7s - loss: 0.0042 - accuracy: 0.9982 - val_loss: 1.1252 - val_accuracy: 0.8301
# Epoch 263/300
#  - 7s - loss: 0.0072 - accuracy: 0.9977 - val_loss: 0.8759 - val_accuracy: 0.8481
# Epoch 264/300
#  - 7s - loss: 0.0033 - accuracy: 0.9990 - val_loss: 1.0181 - val_accuracy: 0.8278
# Epoch 265/300
#  - 7s - loss: 0.0041 - accuracy: 0.9989 - val_loss: 1.0049 - val_accuracy: 0.8421
# Epoch 266/300
#  - 7s - loss: 0.0035 - accuracy: 0.9986 - val_loss: 0.9059 - val_accuracy: 0.8466
# Epoch 267/300
#  - 7s - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.9024 - val_accuracy: 0.8496
# Epoch 268/300
#  - 7s - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.9044 - val_accuracy: 0.8466
# Epoch 269/300
#  - 7s - loss: 0.0040 - accuracy: 0.9988 - val_loss: 0.8800 - val_accuracy: 0.8489
# Epoch 270/300
#  - 7s - loss: 0.0048 - accuracy: 0.9986 - val_loss: 0.9285 - val_accuracy: 0.8331
# Epoch 271/300
#  - 6s - loss: 0.0080 - accuracy: 0.9972 - val_loss: 0.9296 - val_accuracy: 0.8451
# Epoch 272/300
#  - 7s - loss: 0.0123 - accuracy: 0.9957 - val_loss: 0.9582 - val_accuracy: 0.8383
# Epoch 273/300
#  - 7s - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.8878 - val_accuracy: 0.8571
# Epoch 274/300
#  - 7s - loss: 0.0016 - accuracy: 0.9998 - val_loss: 0.8961 - val_accuracy: 0.8474
# Epoch 275/300
#  - 7s - loss: 0.0065 - accuracy: 0.9981 - val_loss: 0.9403 - val_accuracy: 0.8429
# Epoch 276/300
#  - 7s - loss: 0.0033 - accuracy: 0.9994 - val_loss: 0.9522 - val_accuracy: 0.8519
# Epoch 277/300
#  - 7s - loss: 0.0081 - accuracy: 0.9970 - val_loss: 0.9442 - val_accuracy: 0.8564
# Epoch 278/300
#  - 8s - loss: 0.0072 - accuracy: 0.9977 - val_loss: 1.0393 - val_accuracy: 0.8391
# Epoch 279/300
#  - 10s - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.9132 - val_accuracy: 0.8541
# Epoch 280/300
#  - 9s - loss: 0.0053 - accuracy: 0.9983 - val_loss: 0.9277 - val_accuracy: 0.8511
# Epoch 281/300
#  - 7s - loss: 0.0121 - accuracy: 0.9961 - val_loss: 0.9456 - val_accuracy: 0.8361
# Epoch 282/300
#  - 7s - loss: 0.0065 - accuracy: 0.9976 - val_loss: 0.9467 - val_accuracy: 0.8376
# Epoch 283/300
#  - 7s - loss: 0.0033 - accuracy: 0.9992 - val_loss: 0.9753 - val_accuracy: 0.8353
# Epoch 284/300
#  - 7s - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.9657 - val_accuracy: 0.8474
# Epoch 285/300
#  - 7s - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.9569 - val_accuracy: 0.8451
# Epoch 286/300
#  - 7s - loss: 0.0073 - accuracy: 0.9972 - val_loss: 1.0036 - val_accuracy: 0.8429
# Epoch 287/300
#  - 7s - loss: 0.0059 - accuracy: 0.9980 - val_loss: 0.9057 - val_accuracy: 0.8429
# Epoch 288/300
#  - 7s - loss: 0.0053 - accuracy: 0.9986 - val_loss: 0.9080 - val_accuracy: 0.8474
# Epoch 289/300
#  - 7s - loss: 0.0061 - accuracy: 0.9976 - val_loss: 0.8803 - val_accuracy: 0.8519
# Epoch 290/300
#  - 7s - loss: 0.0034 - accuracy: 0.9989 - val_loss: 1.0027 - val_accuracy: 0.8429
# Epoch 291/300
#  - 7s - loss: 0.0055 - accuracy: 0.9977 - val_loss: 0.9452 - val_accuracy: 0.8368
# Epoch 292/300
#  - 7s - loss: 0.0046 - accuracy: 0.9982 - val_loss: 1.0029 - val_accuracy: 0.8383
# Epoch 293/300
#  - 7s - loss: 0.0042 - accuracy: 0.9986 - val_loss: 0.9743 - val_accuracy: 0.8391
# Epoch 294/300
#  - 7s - loss: 0.0023 - accuracy: 0.9993 - val_loss: 0.9354 - val_accuracy: 0.8444
# Epoch 295/300
#  - 6s - loss: 0.0027 - accuracy: 0.9992 - val_loss: 1.0113 - val_accuracy: 0.8474
# Epoch 296/300
#  - 7s - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.9314 - val_accuracy: 0.8504
# Epoch 297/300
#  - 7s - loss: 0.0023 - accuracy: 0.9994 - val_loss: 1.0190 - val_accuracy: 0.8496
# Epoch 298/300
#  - 7s - loss: 0.0058 - accuracy: 0.9979 - val_loss: 1.0192 - val_accuracy: 0.8436
# Epoch 299/300
#  - 6s - loss: 0.0079 - accuracy: 0.9971 - val_loss: 0.9930 - val_accuracy: 0.8338
# Epoch 300/300
#  - 7s - loss: 0.0083 - accuracy: 0.9974 - val_loss: 0.9250 - val_accuracy: 0.8451

# %%
epochs = len(model_fit_history.history['accuracy'])
plt.axis([0, epochs+1, 0, 1.2])
x = np.arange(1, epochs+1)
plt.plot(x, model_fit_history.history['accuracy'])
plt.plot(x, model_fit_history.history['val_accuracy'])
plt.title('Training accuracy vs. Validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='right')
plt.show()

# %%
epochs = len(model_fit_history.history['loss'])
max_loss = max(max(model_fit_history.history['loss']), max(model_fit_history.history['val_loss']))
plt.axis([0, epochs+1, 0, round(max_loss * 2.0) / 2 + 0.5])
x = np.arange(1, epochs+1)
plt.plot(x, model_fit_history.history['loss'])
plt.plot(x, model_fit_history.history['val_loss'])
plt.title('Training loss vs. Validation loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='right')
plt.show()

# %%
epochs = np.argmin(model_fit_history.history['val_loss']) + 1
print(epochs)
# Merge training and validation data
X_train = np.concatenate([X['Train'], X['Validation']])
Y_train = np.concatenate([Y['Train'], Y['Validation']])

# Randomly shuffle X and Y
shuffle_index = np.random.permutation(len(X_train))
X_train = X_train[shuffle_index]
Y_train = Y_train[shuffle_index]
model = build_fully_connected(input_shape=X_train.shape[1:], num_classes=num_classes)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
model_fit_history = model.fit(X_train, Y_train, batch_size=64, epochs=epochs, verbose=0)
# Out:
# 20

# %%
y_pred = model.predict_classes(X['Test'], verbose=0)

# %%
y_test = np.nonzero(Y['Test'])[1]
accuracy = accuracy_score(y_test, y_pred)

# %%
print(accuracy)
print(classification_report(y_test, y_pred))
# Out:
# 0.8518796992481203
#               precision    recall  f1-score   support
#
#            0       0.97      0.84      0.90        70
#            1       0.87      0.86      0.86        70
#            2       0.91      0.89      0.90        70
#            3       1.00      0.97      0.99        70
#            4       0.90      0.76      0.82        70
#            5       0.92      0.97      0.94        70
#            6       0.77      0.79      0.78        70
#            7       0.89      0.90      0.89        70
#            8       0.93      0.97      0.95        70
#            9       0.82      0.83      0.82        70
#           10       0.66      0.66      0.66        70
#           11       0.75      0.87      0.81        70
#           12       0.94      0.90      0.92        70
#           13       0.95      0.90      0.93        70
#           14       0.78      0.89      0.83        70
#           15       0.85      0.86      0.85        70
#           16       0.79      0.96      0.86        70
#           17       0.97      0.93      0.95        70
#           18       0.54      0.46      0.50        70
#
#     accuracy                           0.85      1330
#    macro avg       0.85      0.85      0.85      1330
# weighted avg       0.85      0.85      0.85      1330
